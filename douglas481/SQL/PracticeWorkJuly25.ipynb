-- %% [markdown]
-- Adventure Works 2019 In Class Exercises

-- %%
--Q1
SELECT COUNT(*)
FROM Production.Product P
Where P.ListPrice>1000;
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.066
-- <table><tr><th>(No column name)</th></tr><tr><td>86</td></tr></table>

-- %%
--Q2
SELECT *
--FROM Sales.Store S;
FROM Sales.SalesOrderHeader SO
WHERE SO.TotalDue>100000;
-- Out:
-- (108 rows affected)
-- Total execution time: 00:00:00.028
-- ...
