# %%
from bs4 import BeautifulSoup
import requests
import re
from pprint import pprint

# %%
# creating the movie list

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

worksheet = gc.open('movies').sheet1

# get_all_values gives a list of rows.
rows = worksheet.get_all_values()

# Convert to a DataFrame and render.
import pandas as pd
movies = pd.DataFrame.from_records(rows)
# Out:
# WARNING:google.auth._default:No project ID could be determined. Consider running `gcloud config set project` or setting the GOOGLE_CLOUD_PROJECT environment variable

# %%
movies.head(5)
# Out:
#                           0                1       2                  3  \
# 0                     Title  Year of Release  Rating  Number of Reviews
# 1  The Shawshank Redemption             1994     9.3               2.6M
# 2             The Godfather             1972     9.2               1.8M
# 3           The Dark Knight             2008       9               2.6M
# 4    The Godfather: Part II             1974       9               1.2M
#
#                   4                                                  5  \
# 0  Popularity Index                                         Movie Cast
# 1                66  ['Tim Robbins', 'Morgan Freeman', 'Bob Gunton'...
# 2                17  ['Marlon Brando', 'Al Pacino', 'James Caan', '...
# 3                91  ['Christian Bale', 'Heath Ledger', 'Aaron Eckh...
# 4               102  ['Al Pacino', 'Robert De Niro', 'Robert Duvall...
#
#                       6                                                  7
# 0              Director                                        Description
# 1        Frank Darabont  Two imprisoned men bond over a number of years...
# 2  Francis Ford Coppola  The aging patriarch of an organized crime dyna...
# 3     Christopher Nolan  When the menace known as the Joker wreaks havo...
# 4  Francis Ford Coppola  The early life and career of Vito Corleone in ...

# %%
rating=movies.sort_values(2, ascending=False)

# %%
rating[0]
# Out:
# 0                          Title
# 1       The Shawshank Redemption
# 2                  The Godfather
# 3                The Dark Knight
# 4         The Godfather: Part II
#                  ...
# 178    In the Name of the Father
# 179     The Grand Budapest Hotel
# 180                 Barry Lyndon
# 181           Memories of Murder
# 207                Before Sunset
# Name: 0, Length: 208, dtype: object

# %%
movielist = rating[0].values.tolist()

# %%
## beautiful soup scrapper

# %%
url = 'https://imsdb.com/all-scripts.html'
page = requests.get(url)
soup = BeautifulSoup(page.text, "html.parser")
# <br/><h1>All Movie Scripts on IMSDb (A-Z)</h1><p><a href="/Movie Scripts/10 Things I Hate About You Script.html" title="10 Things I Hate About You Script">10 Things I Hate About You</a> (1997-11 Draft)<br/><i>Written by Karen McCullah Lutz,Kirsten Smith,William Shakespeare</i><br/></p><p>

# %%
moviescripts=soup.find_all('p')

# %%
link=[i['href'] for i in soup.find_all('a', href=True)]

# %%
title=[i['title'] for i in soup.find_all('a', title=True)]

# %%
moviescripts[0]
# Out:
# <p><a href="/Movie Scripts/10 Things I Hate About You Script.html" title="10 Things I Hate About You Script">10 Things I Hate About You</a> (1997-11 Draft)<br/><i>Written by Karen McCullah Lutz,Kirsten Smith,William Shakespeare</i><br/></p>

# %%
title

# %%
scriptdf=scriptdf.drop([0,1,2])

# %%
scriptdf=scriptdf.drop([1214,1215,1216])

# %%
scriptdf.head()
# Out:
#                                Title
# 3  10 Things I Hate About You Script
# 4                          12 Script
# 5              12 and Holding Script
# 6                  12 Monkeys Script
# 7            12 Years a Slave Script

# %%
scriptdf['Title']=scriptdf['Title'].str.replace(' Script', '')

# %%
scriptdf['link']=scriptdf['Title'].str.replace(' ', '-')

# %%
scriptdf.link="https://imsdb.com/scripts/"+scriptdf.link+".html"

# %%
scriptdf.to_csv()
# Out:
# ',Title,link\n3,10 Things I Hate About You,https://imsdb.com/scripts/10-Things-I-Hate-About-You.html\n4,12,https://imsdb.com/scripts/12.html\n5,12 and Holding,https://imsdb.com/scripts/12-and-Holding.html\n6,12 Monkeys,https://imsdb.com/scripts/12-Monkeys.html\n7,12 Years a Slave,https://imsdb.com/scripts/12-Years-a-Slave.html\n8,127 Hours,https://imsdb.com/scripts/127-Hours.html\n9,1492: Conquest of Paradise,https://imsdb.com/scripts/1492:-Conquest-of-Paradise.html\n10,15 Minutes,https://imsdb.com/scripts/15-Minutes.html\n11,17 Again,https://imsdb.com/scripts/17-Again.html\n12,187,https://imsdb.com/scripts/187.html\n13,2001: A Space Odyssey,https://imsdb.com/scripts/2001:-A-Space-Odyssey.html\n14,2012,https://imsdb.com/scripts/2012.html\n15,25th Hour,https://imsdb.com/scripts/25th-Hour.html\n16,28 Days Later,https://imsdb.com/scripts/28-Days-Later.html\n17,30 Minutes or Less,https://imsdb.com/scripts/30-Minutes-or-Less.html\n18,42,https://imsdb.com/scripts/42.html\n19,44 Inch Chest,https://imsdb.com/scripts/44-Inch-Chest.html\n20,48 Hrs.,https://imsdb.com/scripts/48-Hrs..html\n21,50-50,https://imsdb.com/scripts/50-50.html\n22,500 Days of Summer,https://imsdb.com/scripts/500-Days-of-Summer.html\n23,8 Mile,https://imsdb.com/scripts/8-Mile.html\n24,8MM,https://imsdb.com/scripts/8MM.html\n25,9,https://imsdb.com/scripts/9.html\n26,A Few Good Men,https://imsdb.com/scripts/A-Few-Good-Men.html\n27,A Most Violent Year,https://imsdb.com/scripts/A-Most-Violent-Year.html\n28,A Prayer Before Dawn,https://imsdb.com/scripts/A-Prayer-Before-Dawn.html\n29,A Quiet Place,https://imsdb.com/scripts/A-Quiet-Place.html\n30,A Scanner Darkly,https://imsdb.com/scripts/A-Scanner-Darkly.html\n31,A Serious Man,https://imsdb.com/scripts/A-Serious-Man.html\n32,A.I.,https://imsdb.com/scripts/A.I..html\n33,Above the Law,https://imsdb.com/scripts/Above-the-Law.html\n34,Absolute Power,https://imsdb.com/scripts/Absolute-Power.html\n35,"Abyss, The","https://imsdb.com/scripts/Abyss,-The.html"\n36,Ace Ventura: Pet Detective,https://imsdb.com/scripts/Ace-Ventura:-Pet-Detective.html\n37,Adaptation,https://imsdb.com/scripts/Adaptation.html\n38,"Addams Family, The","https://imsdb.com/scripts/Addams-Family,-The.html"\n39,"Adjustment Bureau, The","https://imsdb.com/scripts/Adjustment-Bureau,-The.html"\n40,"Adventures of Buckaroo Banzai Across the Eighth Dimension, The","https://imsdb.com/scripts/Adventures-of-Buckaroo-Banzai-Across-the-Eighth-Dimension,-The.html"\n41,Affliction,https://imsdb.com/scripts/Affliction.html\n42,After School Special,https://imsdb.com/scripts/After-School-Special.html\n43,After.Life,https://imsdb.com/scripts/After.Life.html\n44,Agnes of God,https://imsdb.com/scripts/Agnes-of-God.html\n45,Air Force One,https://imsdb.com/scripts/Air-Force-One.html\n46,Airplane,https://imsdb.com/scripts/Airplane.html\n47,Airplane 2: The Sequel,https://imsdb.com/scripts/Airplane-2:-The-Sequel.html\n48,Aladdin,https://imsdb.com/scripts/Aladdin.html\n49,Ali,https://imsdb.com/scripts/Ali.html\n50,Alien,https://imsdb.com/scripts/Alien.html\n51,Alien 3,https://imsdb.com/scripts/Alien-3.html\n52,Alien Nation,https://imsdb.com/scripts/Alien-Nation.html\n53,Alien vs. Predator,https://imsdb.com/scripts/Alien-vs.-Predator.html\n54,Alien: Resurrection,https://imsdb.com/scripts/Alien:-Resurrection.html\n55,Aliens,https://imsdb.com/scripts/Aliens.html\n56,All About Eve,https://imsdb.com/scripts/All-About-Eve.html\n57,All About Steve,https://imsdb.com/scripts/All-About-Steve.html\n58,All the King\'s Men,https://imsdb.com/scripts/All-the-King\'s-Men.html\n59,All the President\'s Men,https://imsdb.com/scripts/All-the-President\'s-Men.html\n60,Almost Famous,https://imsdb.com/scripts/Almost-Famous.html\n61,Alone in the Dark,https://imsdb.com/scripts/Alone-in-the-Dark.html\n62,Amadeus,https://imsdb.com/scripts/Amadeus.html\n63,Amelia,https://imsdb.com/scripts/Amelia.html\n64,American Beauty,https://imsdb.com/scripts/American-Beauty.html\n65,American Gangster,https://imsdb.com/script ...

# %%
from pathlib import Path  
filepath = Path('/content/drive/MyDrive/DSI_capstone/scriptdf')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
scriptdf.to_csv(filepath)
