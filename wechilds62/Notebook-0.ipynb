-- %%
SELECT
    *
FROM
    Invoices
-- Out:
-- (120 rows affected)
-- Total execution time: 00:00:00.155
-- ...

-- %%
Select
    *
    FROM
        Invoices
-- Out:
-- (120 rows affected)
-- Total execution time: 00:00:00.066
-- ...

-- %%
Select
VendorID
From 
Invoices
-- Out:
-- (120 rows affected)
-- Total execution time: 00:00:00.019
-- ...

-- %%
SELECT *
FROm Invoices
JOIN
Vendors
ON 
INVOICES.VendorID=VENDORS.VendorID
-- Out:
-- (120 rows affected)
-- Total execution time: 00:00:00.037
-- ...

-- %%
SELECT *
FROm Invoices
JOIN
Vendors
ON 
INVOICES.VendorID=VENDORS.VendorID 
SELECT
-- Out:
-- : Msg 207, Level 16, State 1, Line 8
-- Invalid column name 'INVOICEDATE'.
-- : Msg 207, Level 16, State 1, Line 8
-- Invalid column name 'INVOICEDUEDATE'.
-- Total execution time: 00:00:00.005

-- %%
SELECT *
From vendorName
Where 
INVOICES=vENDORNAME
-- Out:
-- : Msg 208, Level 16, State 1, Line 1
-- Invalid object name 'vendorName'.
-- Total execution time: 00:00:00.002
