# %% [markdown]
# ## Parquet <-> CSV and Exercise
#
# ### Exercise
# 1. Generate or copy to this diectory any of the following files:
#     1. Extract of any SQL database
#     1. Imported file from your capstone work
#     1. Any other data from other exercises you have aleady used
# 1. Import into Pandas
# 1. Create at least three new Pandas dataframe outputs ether reproducing prior analytics or new analytics

# %%
# !head  data.dataset.parquet
# Out:
# PAR1�	�L��.	<
# ;
# %
# (
# )
# 9
#
#
# #
# /
# 8
# "
#
#
# 5
#
# 7
# $
#
# -
# E
#
# 0
# B
#
#
# G
# !
#
# ,
# :
#
# J
# Z
# &
#
# 4
# @
# A
# 1
# 3
# +
# F
# 6
# 2
# C
# ?
#
#
# >
# '
#
# *
# H
# =
# L
# P
# D
# K
# I
# N
# M
# Q
# R
# S
# T
# O
# U
# <XV����,��ZZ�o��7����`@(�D�PP,
# ��L(���h��f�p:
# ���(��L��f��,F�K�s �6�
# �I� C�BP��`�"��F��4Z���p=�'ԡ"���ZM`��l���Z��I(R+S"�	�S(�:��c�ul���FH<d����Q�*�ئ �$�$H"
# �M"�$a�.B*�19L�J@b��Ia5��.�D�L��`q�lC����@�\J���d �<5�Rӄ@@C1X�b�R)]4&[�T�P��Bt4���SB�$6�ZuS��PP0�MC&QPRH�0%j�ҫt�&��`� �M�K���c��)�	���.���� T(��A��(���%"��r�!LD�6!46	TdҚ]2�e�<P���KL.1��UjL<���hJ�BBa�\
# ӣ�p}H�m�x��0�%V����hV������D@��)F��h�X�qRl��rPP
# �F@jyj��(�&�G�i$��,a�%��G�(h.�L�V: 6��h�0���AJ�f��n���#���-��`��x�H�ar Qx!
# ͣ�Dd�E���±�|@FAu�If�ΥPf�KI�i�*0 �	(:�FO%YV4WC�p��I�qqT!�fR�=8����Q@X���t>�!fr $�D"A�$&'��@:�����}Z�+Fx�"L�E��6FL3(L��+E�D�!8L����s@V_&b�4I�Ԁ�V�ǥTH�"��B+�Z�Ī�1�3�A�$��A&��a|"���@�����Z�T��b1�D>$NcfXD	�`3�T@����(b�K1<��c��&�F�P�߭�����Er="�G�b+h����&h�4������bЀ�	f�q5&�RcUXH1�Ҹ"�U��j��Js�NŪ�0,
# 	� ��0l�$�ۤ&��7!�&�eDIDT�D� �
# 0��f
# �H[�CjhT��VZ�>
# ���8B��B�Y�̠�H&����C *'M0�<�Fa�<<��B�(\2���	�J���1�T�DI@���Dh
# �@��B���i�6�e�JP&&�T�h

# %%
#be sure to have this notebook in the same folder as your parquet file

#this line of code loads the library into the notebook
import pandas as pd

#this line of code reads the parquet into memory to a Pandas DataFrame 
df = pd.read_parquet('data.dataset.parquet')
df
# Out:
#        age  fnlwgt     education  education-num      marital-status  \
# 0       46  160647     Bachelors             13             Widowed
# 1       60  205934       HS-grad              9           Separated
# 2       26  195327       HS-grad              9       Never-married
# 3       59  184948     Assoc-voc             11            Divorced
# 4       37  243425       HS-grad              9            Divorced
# ...    ...     ...           ...            ...                 ...
# 16276   23  265077     Assoc-voc             11       Never-married
# 16277   41  253060     Bachelors             13  Married-civ-spouse
# 16278   25  143267       HS-grad              9       Never-married
# 16279   50   21095  Some-college             10            Divorced
# 16280   54   32778       HS-grad              9  Married-civ-spouse
#
#          relationship                race     sex  capital-gain  capital-loss  \
# 0           Unmarried               White  Female             0             0
# 1       Not-in-family               White  Female             0             0
# 2           Own-child               White    Male             0             0
# 3       Not-in-family               White    Male             0             0
# 4      Other-relative               White  Female             0             0
# ...               ...                 ...     ...           ...           ...
# 16276   Not-in-family               White  Female             0             0
# 16277         Husband               White    Male          7688             0
# 16278   Not-in-family               White  Female             0             0
# 16279       Unmarried  Asian-Pac-Islander    Male             0             0
# 16280            Wife               White  Female             0             0
#
#        hours-per-week income Scored Labels  Scored Probabilities
# 0                  38  <=50K         <=50K              0.181010
# 1                  25  <=50K         <=50K              0.014068
# 2                  40  <=50K         <=50K              0.009978
# 3                  48  <=50K         <=50K              0.190680
# 4                  50  <=50K         <=50K              0.066199
# ...               ...    ...           ...                   ...
# 16276              40  <=50K         <=50K              0.004806
# 16277              45   >50K          >50K              0.996965
# 16278              48  <=50K         <=50K              0.021528
# 16279              40  <=50K         <=50K              0.091146
# 16280              30  <=50K         <=50K              0.280434
#
# [16281 rows x 14 columns]

# %%
#this line code exports the data into a format for Power BI
df.to_csv('azureml_export.csv')
