# %% [markdown]
# ## Exercise
# 1. Connect to a remote or local SQL database
# 1. Bring data into Python from capstone or sample source
# 1. Do some analysis in Pandas

# %% [markdown]
# ## Table of contents
# 1. [Loading sql extension](#load)
# 2. [Connection to the database](#connect)
# 3. [Querying](#query)
# 4. [Using variables](#variables)
# 5. [pyodbc without Jupyter Magic](#pyodbc)

# %% [markdown]
# # loading sql extension <a class="anchor" id="load"></a>

# %% [markdown]
# First of all, we are loading iPython sql library, then dependencies for work, then the extension to enable "SQL Magic"

# %%
# !pip3 install ipython-sql

# %%
# !pip install pyodbc

# %%
import pandas as pd 
import pyodbc
import numpy as np
import matplotlib as plt

# %matplotlib inline

# %%
 # !dir

# %%
# %load_ext sql

# %% [markdown]
# # how to connect to the database <a class="anchor" id="connect"></a>

# %% [markdown]
# Change the connection string to your database to play with the commands
#
# Connection to the sql server database using SQL Alchemy (Object Relational Mapper for Python)
# Connection string format 'mssql+pyodbc://user:password@server/database?DRIVER={enty in /etc/odbcinst.ini}'

# %%
# %sql mssql+pyodbc://@dsiwddsn

# %%
# %sql select * from information_schema.columns
# Out:
#  * mssql+pyodbc://@dsiwddsn
# Done.
# [('AdventureWorks2019', 'HumanResources', 'EmployeePayHistory', 'BusinessEntityID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'EmployeePayHistory', 'RateChangeDate', 2, None, 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'EmployeePayHistory', 'Rate', 3, None, 'NO', 'money', None, None, 19, 10, 4, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'EmployeePayHistory', 'PayFrequency', 4, None, 'NO', 'tinyint', None, None, 3, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'EmployeePayHistory', 'ModifiedDate', 5, '(getdate())', 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesOrderHeaderSalesReason', 'SalesOrderID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesOrderHeaderSalesReason', 'SalesReasonID', 2, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesOrderHeaderSalesReason', 'ModifiedDate', 3, '(getdate())', 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesPerson', 'BusinessEntityID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesPerson', 'TerritoryID', 2, None, 'YES', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesPerson', 'SalesQuota', 3, None, 'YES', 'money', None, None, 19, 10, 4, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesPerson', 'Bonus', 4, '((0.00))', 'NO', 'money', None, None, 19, 10, 4, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesPerson', 'CommissionPct', 5, '((0.00))', 'NO', 'smallmoney', None, None, 10, 10, 4, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesPerson', 'SalesYTD', 6, '((0.00))', 'NO', 'money', None, None, 19, 10, 4, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesPerson', 'SalesLastYear', 7, '((0.00))', 'NO', 'money', None, None, 19, 10, 4, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesPerson', 'rowguid', 8, '(newid())', 'NO', 'uniqueidentifier', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesPerson', 'ModifiedDate', 9, '(getdate())', 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Production', 'Illustration', 'IllustrationID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Production', 'Illustration', 'Diagram', 2, None, 'YES', 'xml', -1, -1, None, None, None, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Production', 'Illustration', 'ModifiedDate', 3, '(getdate())', 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Production', 'UpdatedInventory', 'ProductID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Production', 'UpdatedInventory', 'LocationID', 2, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Production', 'UpdatedInventory', 'NewQty', 3, None, 'YES', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Production', 'UpdatedInventory', 'PreviousQty', 4, None, 'YES', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'JobCandidate', 'JobCandidateID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'JobCandidate', 'BusinessEntityID', 2, None, 'YES', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'JobCandidate', 'Resume', 3, None, 'YES', 'xml', -1, -1, None, None, None, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'JobCandidate', 'ModifiedDate', 4, '(getdate())', 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Production', 'Location', 'LocationID', 1, None, 'NO', 'smallint', None, None, 5, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Production', 'Location', 'Name', 2, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', 'AdventureWorks2019', 'dbo', 'Name'),
#  ('AdventureWorks2019', 'Production', 'Location', 'CostRate', 3, '((0.00))', 'NO', 'smallmoney', None, None, 10, 10, 4, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Production', 'Location', 'Availability', 4, '((0.00))', 'NO', 'decimal', None, None, 8, 10, 2, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Production', 'Location', 'ModifiedDate', 5, '(getdate())', 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Person', 'Password', 'BusinessEntityID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Person', 'Password', 'PasswordHash', 2, None, 'NO', 'varchar', 128, 128, None, None, None, None, None, None, 'iso_1', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'Person', 'Password', 'PasswordSalt', 3, None, 'NO', 'varchar', 10, 10, None, None, None, None, None, None, 'iso_1', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'Person', 'Password', 'rowguid', 4, '(newid())', 'NO', 'uniqueidentifier', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Person', 'Password', 'ModifiedDate', 5, '(getdate())', 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesPersonQuotaHistory', 'BusinessEntityID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesPersonQuotaHistory', 'QuotaDate', 2, None, 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesPersonQuotaHistory', 'SalesQuota', 3, None, 'NO', 'money', None, None, 19, 10, 4, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesPersonQuotaHistory', 'rowguid', 4, '(newid())', 'NO', 'uniqueidentifier', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesPersonQuotaHistory', 'ModifiedDate', 5, '(getdate())', 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Person', 'Person', 'BusinessEntityID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Person', 'Person', 'PersonType', 2, None, 'NO', 'nchar', 2, 4, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'Person', 'Person', 'NameStyle', 3, '((0))', 'NO', 'bit', None, None, None, None, None, None, None, None, None, None, None, None, 'AdventureWorks2019', 'dbo', 'NameStyle'),
#  ('AdventureWorks2019', 'Person', 'Person', 'Title', 4, None, 'YES', 'nvarchar', 8, 16, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'Person', 'Person', 'FirstName', 5, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', 'AdventureWorks2019', 'dbo', 'Name'),
#  ('AdventureWorks2019', 'Person', 'Person', 'MiddleName', 6, None, 'YES', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', 'AdventureWorks2019', 'dbo', 'Name'),
#  ('AdventureWorks2019', 'Person', 'Person', 'LastName', 7, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', 'AdventureWorks2019', 'dbo', 'Name'),
#  ('AdventureWorks2019', 'Person', 'Person', 'Suffix', 8, None, 'YES', 'nvarchar', 10, 20, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'Person', 'Person', 'EmailPromotion', 9, '((0))', 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Person', 'Person', 'AdditionalContactInfo', 10, None, 'YES', 'xml', -1, -1, None, None, None, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Person', 'Person', 'Demographics', 11, None, 'YES', 'xml', -1, -1, None, None, None, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Person', 'Person', 'rowguid', 12, '(newid())', 'NO', 'uniqueidentifier', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Person', 'Person', 'ModifiedDate', 13, '(getdate())', 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Person', 'Person', 'jsoninfo', 14, None, 'YES', 'nvarchar', -1, -1, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesReason', 'SalesReasonID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesReason', 'Name', 2, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', 'AdventureWorks2019', 'dbo', 'Name'),
#  ('AdventureWorks2019', 'Sales', 'SalesReason', 'ReasonType', 3, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', 'AdventureWorks2019', 'dbo', 'Name'),
#  ('AdventureWorks2019', 'Sales', 'SalesReason', 'ModifiedDate', 4, '(getdate())', 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesTaxRate', 'SalesTaxRateID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesTaxRate', 'StateProvinceID', 2, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesTaxRate', 'TaxType', 3, None, 'NO', 'tinyint', None, None, 3, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesTaxRate', 'TaxRate', 4, '((0.00))', 'NO', 'smallmoney', None, None, 10, 10, 4, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesTaxRate', 'Name', 5, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', 'AdventureWorks2019', 'dbo', 'Name'),
#  ('AdventureWorks2019', 'Sales', 'SalesTaxRate', 'rowguid', 6, '(newid())', 'NO', 'uniqueidentifier', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesTaxRate', 'ModifiedDate', 7, '(getdate())', 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'PersonCreditCard', 'BusinessEntityID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'PersonCreditCard', 'CreditCardID', 2, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'PersonCreditCard', 'ModifiedDate', 3, '(getdate())', 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Person', 'vAdditionalContactInfo', 'BusinessEntityID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Person', 'vAdditionalContactInfo', 'FirstName', 2, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', 'AdventureWorks2019', 'dbo', 'Name'),
#  ('AdventureWorks2019', 'Person', 'vAdditionalContactInfo', 'MiddleName', 3, None, 'YES', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', 'AdventureWorks2019', 'dbo', 'Name'),
#  ('AdventureWorks2019', 'Person', 'vAdditionalContactInfo', 'LastName', 4, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', 'AdventureWorks2019', 'dbo', 'Name'),
#  ('AdventureWorks2019', 'Person', 'vAdditionalContactInfo', 'TelephoneNumber', 5, None, 'YES', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'Person', 'vAdditionalContactInfo', 'TelephoneSpecialInstructions', 6, None, 'YES', 'nvarchar', -1, -1, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'Person', 'vAdditionalContactInfo', 'Street', 7, None, 'YES', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'Person', 'vAdditionalContactInfo', 'City', 8, None, 'YES', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'Person', 'vAdditionalContactInfo', 'StateProvince', 9, None, 'YES', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'Person', 'vAdditionalContactInfo', 'PostalCode', 10, None, 'YES', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'Person', 'vAdditionalContactInfo', 'CountryRegion', 11, None, 'YES', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'Person', 'vAdditionalContactInfo', 'HomeAddressSpecialInstructions', 12, None, 'YES', 'nvarchar', -1, -1, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'Person', 'vAdditionalContactInfo', 'EMailAddress', 13, None, 'YES', 'nvarchar', 128, 256, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'Person', 'vAdditionalContactInfo', 'EMailSpecialInstructions', 14, None, 'YES', 'nvarchar', -1, -1, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'Person', 'vAdditionalContactInfo', 'EMailTelephoneNumber', 15, None, 'YES', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'Person', 'vAdditionalContactInfo', 'rowguid', 16, None, 'NO', 'uniqueidentifier', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Person', 'vAdditionalContactInfo', 'ModifiedDate', 17, None, 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Person', 'PersonPhone', 'BusinessEntityID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Person', 'PersonPhone', 'PhoneNumber', 2, None, 'NO', 'nvarchar', 25, 50, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', 'AdventureWorks2019', 'dbo', 'Phone'),
#  ('AdventureWorks2019', 'Person', 'PersonPhone', 'PhoneNumberTypeID', 3, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Person', 'PersonPhone', 'ModifiedDate', 4, '(getdate())', 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Purchasing', 'PurchaseOrderPivot', 'VendorID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Purchasing', 'PurchaseOrderPivot', 'Emp1', 2, None, 'YES', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Purchasing', 'PurchaseOrderPivot', 'Emp2', 3, None, 'YES', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Purchasing', 'PurchaseOrderPivot', 'Emp3', 4, None, 'YES', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Purchasing', 'PurchaseOrderPivot', 'Emp4', 5, None, 'YES', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Purchasing', 'PurchaseOrderPivot', 'Emp5', 6, None, 'YES', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'vEmployee', 'BusinessEntityID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'vEmployee', 'Title', 2, None, 'YES', 'nvarchar', 8, 16, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'vEmployee', 'FirstName', 3, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', 'AdventureWorks2019', 'dbo', 'Name'),
#  ('AdventureWorks2019', 'HumanResources', 'vEmployee', 'MiddleName', 4, None, 'YES', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', 'AdventureWorks2019', 'dbo', 'Name'),
#  ('AdventureWorks2019', 'HumanResources', 'vEmployee', 'LastName', 5, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', 'AdventureWorks2019', 'dbo', 'Name'),
#  ('AdventureWorks2019', 'HumanResources', 'vEmployee', 'Suffix', 6, None, 'YES', 'nvarchar', 10, 20, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'vEmployee', 'JobTitle', 7, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'vEmployee', 'PhoneNumber', 8, None, 'YES', 'nvarchar', 25, 50, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', 'AdventureWorks2019', 'dbo', 'Phone'),
#  ('AdventureWorks2019', 'HumanResources', 'vEmployee', 'PhoneNumberType', 9, None, 'YES', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', 'AdventureWorks2019', 'dbo', 'Name'),
#  ('AdventureWorks2019', 'HumanResources', 'vEmployee', 'EmailAddress', 10, None, 'YES', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'vEmployee', 'EmailPromotion', 11, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'vEmployee', 'AddressLine1', 12, None, 'NO', 'nvarchar', 60, 120, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'vEmployee', 'AddressLine2', 13, None, 'YES', 'nvarchar', 60, 120, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'vEmployee', 'City', 14, None, 'NO', 'nvarchar', 30, 60, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'vEmployee', 'StateProvinceName', 15, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', 'AdventureWorks2019', 'dbo', 'Name'),
#  ('AdventureWorks2019', 'HumanResources', 'vEmployee', 'PostalCode', 16, None, 'NO', 'nvarchar', 15, 30, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'vEmployee', 'CountryRegionName', 17, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', 'AdventureWorks2019', 'dbo', 'Name'),
#  ('AdventureWorks2019', 'HumanResources', 'vEmployee', 'AdditionalContactInfo', 18, None, 'YES', 'xml', -1, -1, None, None, None, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesTerritory', 'TerritoryID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesTerritory', 'Name', 2, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', 'AdventureWorks2019', 'dbo', 'Name'),
#  ('AdventureWorks2019', 'Sales', 'SalesTerritory', 'CountryRegionCode', 3, None, 'NO', 'nvarchar', 3, 6, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesTerritory', 'Group', 4, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesTerritory', 'SalesYTD', 5, '((0.00))', 'NO', 'money', None, None, 19, 10, 4, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesTerritory', 'SalesLastYear', 6, '((0.00))', 'NO', 'money', None, None, 19, 10, 4, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesTerritory', 'CostYTD', 7, '((0.00))', 'NO', 'money', None, None, 19, 10, 4, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesTerritory', 'CostLastYear', 8, '((0.00))', 'NO', 'money', None, None, 19, 10, 4, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesTerritory', 'rowguid', 9, '(newid())', 'NO', 'uniqueidentifier', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesTerritory', 'ModifiedDate', 10, '(getdate())', 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'vEmployeeDepartment', 'BusinessEntityID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'vEmployeeDepartment', 'Title', 2, None, 'YES', 'nvarchar', 8, 16, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'vEmployeeDepartment', 'FirstName', 3, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', 'AdventureWorks2019', 'dbo', 'Name'),
#  ('AdventureWorks2019', 'HumanResources', 'vEmployeeDepartment', 'MiddleName', 4, None, 'YES', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', 'AdventureWorks2019', 'dbo', 'Name'),
#  ('AdventureWorks2019', 'HumanResources', 'vEmployeeDepartment', 'LastName', 5, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', 'AdventureWorks2019', 'dbo', 'Name'),
#  ('AdventureWorks2019', 'HumanResources', 'vEmployeeDepartment', 'Suffix', 6, None, 'YES', 'nvarchar', 10, 20, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'vEmployeeDepartment', 'JobTitle', 7, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'vEmployeeDepartment', 'Department', 8, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', 'AdventureWorks2019', 'dbo', 'Name'),
#  ('AdventureWorks2019', 'HumanResources', 'vEmployeeDepartment', 'GroupName', 9, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', 'AdventureWorks2019', 'dbo', 'Name'),
#  ('AdventureWorks2019', 'HumanResources', 'vEmployeeDepartment', 'StartDate', 10, None, 'NO', 'date', None, None, None, None, None, 0, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Person', 'PhoneNumberType', 'PhoneNumberTypeID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Person', 'PhoneNumberType', 'Name', 2, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', 'AdventureWorks2019', 'dbo', 'Name'),
#  ('AdventureWorks2019', 'Person', 'PhoneNumberType', 'ModifiedDate', 3, '(getdate())', 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'vEmployeeDepartmentHistory', 'BusinessEntityID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'vEmployeeDepartmentHistory', 'Title', 2, None, 'YES', 'nvarchar', 8, 16, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'vEmployeeDepartmentHistory', 'FirstName', 3, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', 'AdventureWorks2019', 'dbo', 'Name'),
#  ('AdventureWorks2019', 'HumanResources', 'vEmployeeDepartmentHistory', 'MiddleName', 4, None, 'YES', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', 'AdventureWorks2019', 'dbo', 'Name'),
#  ('AdventureWorks2019', 'HumanResources', 'vEmployeeDepartmentHistory', 'LastName', 5, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', 'AdventureWorks2019', 'dbo', 'Name'),
#  ('AdventureWorks2019', 'HumanResources', 'vEmployeeDepartmentHistory', 'Suffix', 6, None, 'YES', 'nvarchar', 10, 20, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'vEmployeeDepartmentHistory', 'Shift', 7, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', 'AdventureWorks2019', 'dbo', 'Name'),
#  ('AdventureWorks2019', 'HumanResources', 'vEmployeeDepartmentHistory', 'Department', 8, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', 'AdventureWorks2019', 'dbo', 'Name'),
#  ('AdventureWorks2019', 'HumanResources', 'vEmployeeDepartmentHistory', 'GroupName', 9, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', 'AdventureWorks2019', 'dbo', 'Name'),
#  ('AdventureWorks2019', 'HumanResources', 'vEmployeeDepartmentHistory', 'StartDate', 10, None, 'NO', 'date', None, None, None, None, None, 0, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'vEmployeeDepartmentHistory', 'EndDate', 11, None, 'YES', 'date', None, None, None, None, None, 0, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'vIndividualCustomer', 'BusinessEntityID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'vIndividualCustomer', 'Title', 2, None, 'YES', 'nvarchar', 8, 16, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'Sales', 'vIndividualCustomer', 'FirstName', 3, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', 'AdventureWorks2019', 'dbo', 'Name'),
#  ('AdventureWorks2019', 'Sales', 'vIndividualCustomer', 'MiddleName', 4, None, 'YES', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', 'AdventureWorks2019', 'dbo', 'Name'),
#  ('AdventureWorks2019', 'Sales', 'vIndividualCustomer', 'LastName', 5, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', 'AdventureWorks2019', 'dbo', 'Name'),
#  ('AdventureWorks2019', 'Sales', 'vIndividualCustomer', 'Suffix', 6, None, 'YES', 'nvarchar', 10, 20, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'Sales', 'vIndividualCustomer', 'PhoneNumber', 7, None, 'YES', 'nvarchar', 25, 50, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', 'AdventureWorks2019', 'dbo', 'Phone'),
#  ('AdventureWorks2019', 'Sales', 'vIndividualCustomer', 'PhoneNumberType', 8, None, 'YES', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', 'AdventureWorks2019', 'dbo', 'Name'),
#  ('AdventureWorks2019', 'Sales', 'vIndividualCustomer', 'EmailAddress', 9, None, 'YES', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'Sales', 'vIndividualCustomer', 'EmailPromotion', 10, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'vIndividualCustomer', 'AddressType', 11, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', 'AdventureWorks2019', 'dbo', 'Name'),
#  ('AdventureWorks2019', 'Sales', 'vIndividualCustomer', 'AddressLine1', 12, None, 'NO', 'nvarchar', 60, 120, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'Sales', 'vIndividualCustomer', 'AddressLine2', 13, None, 'YES', 'nvarchar', 60, 120, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'Sales', 'vIndividualCustomer', 'City', 14, None, 'NO', 'nvarchar', 30, 60, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'Sales', 'vIndividualCustomer', 'StateProvinceName', 15, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', 'AdventureWorks2019', 'dbo', 'Name'),
#  ('AdventureWorks2019', 'Sales', 'vIndividualCustomer', 'PostalCode', 16, None, 'NO', 'nvarchar', 15, 30, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'Sales', 'vIndividualCustomer', 'CountryRegionName', 17, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', 'AdventureWorks2019', 'dbo', 'Name'),
#  ('AdventureWorks2019', 'Sales', 'vIndividualCustomer', 'Demographics', 18, None, 'YES', 'xml', -1, -1, None, None, None, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Production', 'Product', 'ProductID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Production', 'Product', 'Name', 2, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', 'AdventureWorks2019', 'dbo', 'Name'),
#  ('AdventureWorks2019', 'Production', 'Product', 'ProductNumber', 3, None, 'NO', 'nvarchar', 25, 50, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'Production', 'Product', 'MakeFlag', 4, '((1))', 'NO', 'bit', None, None, None, None, None, None, None, None, None, None, None, None, 'AdventureWorks2019', 'dbo', 'Flag'),
#  ('AdventureWorks2019', 'Production', 'Product', 'FinishedGoodsFlag', 5, '((1))', 'NO', 'bit', None, None, None, None, None, None, None, None, None, None, None, None, 'AdventureWorks2019', 'dbo', 'Flag'),
#  ('AdventureWorks2019', 'Production', 'Product', 'Color', 6, None, 'YES', 'nvarchar', 15, 30, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'Production', 'Product', 'SafetyStockLevel', 7, None, 'NO', 'smallint', None, None, 5, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Production', 'Product', 'ReorderPoint', 8, None, 'NO', 'smallint', None, None, 5, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Production', 'Product', 'StandardCost', 9, None, 'NO', 'money', None, None, 19, 10, 4, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Production', 'Product', 'ListPrice', 10, None, 'NO', 'money', None, None, 19, 10, 4, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Production', 'Product', 'Size', 11, None, 'YES', 'nvarchar', 5, 10, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'Production', 'Product', 'SizeUnitMeasureCode', 12, None, 'YES', 'nchar', 3, 6, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'Production', 'Product', 'WeightUnitMeasureCode', 13, None, 'YES', 'nchar', 3, 6, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'Production', 'Product', 'Weight', 14, None, 'YES', 'decimal', None, None, 8, 10, 2, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Production', 'Product', 'DaysToManufacture', 15, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Production', 'Product', 'ProductLine', 16, None, 'YES', 'nchar', 2, 4, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'Production', 'Product', 'Class', 17, None, 'YES', 'nchar', 2, 4, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'Production', 'Product', 'Style', 18, None, 'YES', 'nchar', 2, 4, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'Production', 'Product', 'ProductSubcategoryID', 19, None, 'YES', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Production', 'Product', 'ProductModelID', 20, None, 'YES', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Production', 'Product', 'SellStartDate', 21, None, 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Production', 'Product', 'SellEndDate', 22, None, 'YES', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Production', 'Product', 'DiscontinuedDate', 23, None, 'YES', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Production', 'Product', 'rowguid', 24, '(newid())', 'NO', 'uniqueidentifier', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Production', 'Product', 'ModifiedDate', 25, '(getdate())', 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'vPersonDemographics', 'BusinessEntityID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'vPersonDemographics', 'TotalPurchaseYTD', 2, None, 'YES', 'money', None, None, 19, 10, 4, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'vPersonDemographics', 'DateFirstPurchase', 3, None, 'YES', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'vPersonDemographics', 'BirthDate', 4, None, 'YES', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'vPersonDemographics', 'MaritalStatus', 5, None, 'YES', 'nvarchar', 1, 2, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'Sales', 'vPersonDemographics', 'YearlyIncome', 6, None, 'YES', 'nvarchar', 30, 60, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'Sales', 'vPersonDemographics', 'Gender', 7, None, 'YES', 'nvarchar', 1, 2, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'Sales', 'vPersonDemographics', 'TotalChildren', 8, None, 'YES', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'vPersonDemographics', 'NumberChildrenAtHome', 9, None, 'YES', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'vPersonDemographics', 'Education', 10, None, 'YES', 'nvarchar', 30, 60, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'Sales', 'vPersonDemographics', 'Occupation', 11, None, 'YES', 'nvarchar', 30, 60, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'Sales', 'vPersonDemographics', 'HomeOwnerFlag', 12, None, 'YES', 'bit', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'vPersonDemographics', 'NumberCarsOwned', 13, None, 'YES', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'vJobCandidate', 'JobCandidateID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'vJobCandidate', 'BusinessEntityID', 2, None, 'YES', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'vJobCandidate', 'Name.Prefix', 3, None, 'YES', 'nvarchar', 30, 60, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'vJobCandidate', 'Name.First', 4, None, 'YES', 'nvarchar', 30, 60, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'vJobCandidate', 'Name.Middle', 5, None, 'YES', 'nvarchar', 30, 60, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'vJobCandidate', 'Name.Last', 6, None, 'YES', 'nvarchar', 30, 60, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'vJobCandidate', 'Name.Suffix', 7, None, 'YES', 'nvarchar', 30, 60, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'vJobCandidate', 'Skills', 8, None, 'YES', 'nvarchar', -1, -1, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'vJobCandidate', 'Addr.Type', 9, None, 'YES', 'nvarchar', 30, 60, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'vJobCandidate', 'Addr.Loc.CountryRegion', 10, None, 'YES', 'nvarchar', 100, 200, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'vJobCandidate', 'Addr.Loc.State', 11, None, 'YES', 'nvarchar', 100, 200, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'vJobCandidate', 'Addr.Loc.City', 12, None, 'YES', 'nvarchar', 100, 200, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'vJobCandidate', 'Addr.PostalCode', 13, None, 'YES', 'nvarchar', 20, 40, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'vJobCandidate', 'EMail', 14, None, 'YES', 'nvarchar', -1, -1, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'vJobCandidate', 'WebSite', 15, None, 'YES', 'nvarchar', -1, -1, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'vJobCandidate', 'ModifiedDate', 16, None, 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'vJobCandidateEmployment', 'JobCandidateID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'vJobCandidateEmployment', 'Emp.StartDate', 2, None, 'YES', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'vJobCandidateEmployment', 'Emp.EndDate', 3, None, 'YES', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'vJobCandidateEmployment', 'Emp.OrgName', 4, None, 'YES', 'nvarchar', 100, 200, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'vJobCandidateEmployment', 'Emp.JobTitle', 5, None, 'YES', 'nvarchar', 100, 200, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'vJobCandidateEmployment', 'Emp.Responsibility', 6, None, 'YES', 'nvarchar', -1, -1, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'vJobCandidateEmployment', 'Emp.FunctionCategory', 7, None, 'YES', 'nvarchar', -1, -1, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'vJobCandidateEmployment', 'Emp.IndustryCategory', 8, None, 'YES', 'nvarchar', -1, -1, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'vJobCandidateEmployment', 'Emp.Loc.CountryRegion', 9, None, 'YES', 'nvarchar', -1, -1, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'vJobCandidateEmployment', 'Emp.Loc.State', 10, None, 'YES', 'nvarchar', -1, -1, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'vJobCandidateEmployment', 'Emp.Loc.City', 11, None, 'YES', 'nvarchar', -1, -1, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'vJobCandidateEducation', 'JobCandidateID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'vJobCandidateEducation', 'Edu.Level', 2, None, 'YES', 'nvarchar', -1, -1, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
# ...
#  ('AdventureWorks2019', 'Production', 'Document', 'FileName', 6, None, 'NO', 'nvarchar', 400, 800, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'Production', 'Document', 'FileExtension', 7, None, 'NO', 'nvarchar', 8, 16, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'Production', 'Document', 'Revision', 8, None, 'NO', 'nchar', 5, 10, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'Production', 'Document', 'ChangeNumber', 9, '((0))', 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Production', 'Document', 'Status', 10, None, 'NO', 'tinyint', None, None, 3, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Production', 'Document', 'DocumentSummary', 11, None, 'YES', 'nvarchar', -1, -1, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'Production', 'Document', 'Document', 12, None, 'YES', 'varbinary', -1, -1, None, None, None, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Production', 'Document', 'rowguid', 13, '(newid())', 'NO', 'uniqueidentifier', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Production', 'Document', 'ModifiedDate', 14, '(getdate())', 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesOrderDetail', 'SalesOrderID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesOrderDetail', 'SalesOrderDetailID', 2, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesOrderDetail', 'CarrierTrackingNumber', 3, None, 'YES', 'nvarchar', 25, 50, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesOrderDetail', 'OrderQty', 4, None, 'NO', 'smallint', None, None, 5, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesOrderDetail', 'ProductID', 5, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesOrderDetail', 'SpecialOfferID', 6, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesOrderDetail', 'UnitPrice', 7, None, 'NO', 'money', None, None, 19, 10, 4, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesOrderDetail', 'UnitPriceDiscount', 8, '((0.0))', 'NO', 'money', None, None, 19, 10, 4, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesOrderDetail', 'LineTotal', 9, None, 'NO', 'numeric', None, None, 38, 10, 6, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesOrderDetail', 'rowguid', 10, '(newid())', 'NO', 'uniqueidentifier', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesOrderDetail', 'ModifiedDate', 11, '(getdate())', 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Person', 'EmailAddress', 'BusinessEntityID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Person', 'EmailAddress', 'EmailAddressID', 2, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Person', 'EmailAddress', 'EmailAddress', 3, None, 'YES', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'Person', 'EmailAddress', 'rowguid', 4, '(newid())', 'NO', 'uniqueidentifier', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Person', 'EmailAddress', 'ModifiedDate', 5, '(getdate())', 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'Employee', 'BusinessEntityID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'Employee', 'NationalIDNumber', 2, None, 'NO', 'nvarchar', 15, 30, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'Employee', 'LoginID', 3, None, 'NO', 'nvarchar', 256, 512, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'Employee', 'OrganizationNode', 4, None, 'YES', 'hierarchyid', 892, 892, None, None, None, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'Employee', 'OrganizationLevel', 5, None, 'YES', 'smallint', None, None, 5, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'Employee', 'JobTitle', 6, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'Employee', 'BirthDate', 7, None, 'NO', 'date', None, None, None, None, None, 0, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'Employee', 'MaritalStatus', 8, None, 'NO', 'nchar', 1, 2, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'Employee', 'Gender', 9, None, 'NO', 'nchar', 1, 2, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'Employee', 'HireDate', 10, None, 'NO', 'date', None, None, None, None, None, 0, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'Employee', 'SalariedFlag', 11, '((1))', 'NO', 'bit', None, None, None, None, None, None, None, None, None, None, None, None, 'AdventureWorks2019', 'dbo', 'Flag'),
#  ('AdventureWorks2019', 'HumanResources', 'Employee', 'VacationHours', 12, '((0))', 'NO', 'smallint', None, None, 5, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'Employee', 'SickLeaveHours', 13, '((0))', 'NO', 'smallint', None, None, 5, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'Employee', 'CurrentFlag', 14, '((1))', 'NO', 'bit', None, None, None, None, None, None, None, None, None, None, None, None, 'AdventureWorks2019', 'dbo', 'Flag'),
#  ('AdventureWorks2019', 'HumanResources', 'Employee', 'rowguid', 15, '(newid())', 'NO', 'uniqueidentifier', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'Employee', 'ModifiedDate', 16, '(getdate())', 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'dbo', 'Students', 'StudentID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'dbo', 'Students', 'StudentName', 2, None, 'YES', 'char', 500, 500, None, None, None, None, None, None, 'iso_1', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesOrderHeader', 'SalesOrderID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesOrderHeader', 'RevisionNumber', 2, '((0))', 'NO', 'tinyint', None, None, 3, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesOrderHeader', 'OrderDate', 3, '(getdate())', 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesOrderHeader', 'DueDate', 4, None, 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesOrderHeader', 'ShipDate', 5, None, 'YES', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesOrderHeader', 'Status', 6, '((1))', 'NO', 'tinyint', None, None, 3, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesOrderHeader', 'OnlineOrderFlag', 7, '((1))', 'NO', 'bit', None, None, None, None, None, None, None, None, None, None, None, None, 'AdventureWorks2019', 'dbo', 'Flag'),
#  ('AdventureWorks2019', 'Sales', 'SalesOrderHeader', 'SalesOrderNumber', 8, None, 'NO', 'nvarchar', 25, 50, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesOrderHeader', 'PurchaseOrderNumber', 9, None, 'YES', 'nvarchar', 25, 50, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', 'AdventureWorks2019', 'dbo', 'OrderNumber'),
#  ('AdventureWorks2019', 'Sales', 'SalesOrderHeader', 'AccountNumber', 10, None, 'YES', 'nvarchar', 15, 30, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', 'AdventureWorks2019', 'dbo', 'AccountNumber'),
#  ('AdventureWorks2019', 'Sales', 'SalesOrderHeader', 'CustomerID', 11, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesOrderHeader', 'SalesPersonID', 12, None, 'YES', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesOrderHeader', 'TerritoryID', 13, None, 'YES', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesOrderHeader', 'BillToAddressID', 14, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesOrderHeader', 'ShipToAddressID', 15, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesOrderHeader', 'ShipMethodID', 16, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesOrderHeader', 'CreditCardID', 17, None, 'YES', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesOrderHeader', 'CreditCardApprovalCode', 18, None, 'YES', 'varchar', 15, 15, None, None, None, None, None, None, 'iso_1', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesOrderHeader', 'CurrencyRateID', 19, None, 'YES', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesOrderHeader', 'SubTotal', 20, '((0.00))', 'NO', 'money', None, None, 19, 10, 4, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesOrderHeader', 'TaxAmt', 21, '((0.00))', 'NO', 'money', None, None, 19, 10, 4, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesOrderHeader', 'Freight', 22, '((0.00))', 'NO', 'money', None, None, 19, 10, 4, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesOrderHeader', 'TotalDue', 23, None, 'NO', 'money', None, None, 19, 10, 4, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesOrderHeader', 'Comment', 24, None, 'YES', 'nvarchar', 128, 256, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesOrderHeader', 'rowguid', 25, '(newid())', 'NO', 'uniqueidentifier', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'Sales', 'SalesOrderHeader', 'ModifiedDate', 26, '(getdate())', 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'dbo', 'vSpecialOffers', 'Name', 1, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', 'AdventureWorks2019', 'dbo', 'Name'),
#  ('AdventureWorks2019', 'dbo', 'vSpecialOffers', 'TotalSales', 2, None, 'YES', 'money', None, None, 19, 10, 4, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'dbo', 'vSpecialOffers', 'NumOffers', 3, None, 'YES', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'dbo', 'sysdiagrams', 'name', 1, None, 'NO', 'nvarchar', 128, 256, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('AdventureWorks2019', 'dbo', 'sysdiagrams', 'principal_id', 2, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'dbo', 'sysdiagrams', 'diagram_id', 3, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'dbo', 'sysdiagrams', 'version', 4, None, 'YES', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'dbo', 'sysdiagrams', 'definition', 5, None, 'YES', 'varbinary', -1, -1, None, None, None, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'EmployeeDepartmentHistory', 'BusinessEntityID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'EmployeeDepartmentHistory', 'DepartmentID', 2, None, 'NO', 'smallint', None, None, 5, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'EmployeeDepartmentHistory', 'ShiftID', 3, None, 'NO', 'tinyint', None, None, 3, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'EmployeeDepartmentHistory', 'StartDate', 4, None, 'NO', 'date', None, None, None, None, None, 0, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'EmployeeDepartmentHistory', 'EndDate', 5, None, 'YES', 'date', None, None, None, None, None, 0, None, None, None, None, None, None, None, None, None),
#  ('AdventureWorks2019', 'HumanResources', 'EmployeeDepartmentHistory', 'ModifiedDate', 6, '(getdate())', 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None)]

# %% [markdown]
# # querying <a class="anchor" id="query"></a>

# %% [markdown]
# Lets start with a simple query <br>
# If your query is short, you can write one-liner code:

# %%
f = 4
r = 5
f+r

# %%
# %sql SELECT TOP 10 *  FROM [Sales].[SalesOrderDetail]

# %% [markdown]
# If the query spans several lines, you can put the query into the variable and execute it:

# %%
var = "C:\\"
# !dir $var

# %%
db_query = '''
SELECT VendorID, [250] AS Emp1, [251] AS Employee, [256] AS Emp3, [257] AS Emp4, [260] AS Emp5  
FROM   
(SELECT PurchaseOrderID, EmployeeID, VendorID  
FROM Purchasing.PurchaseOrderHeader) p  
PIVOT  
(  
COUNT (PurchaseOrderID)  
FOR EmployeeID IN  
( [250], [251], [256], [257], [260] )  
) AS pvt  
ORDER BY pvt.VendorID;  '''

# %%
# %sql $db_query

# %% [markdown]
# # using variables <a class="anchor" id="variables"></a>

# %%
customerid = 11000

# %% [markdown]
# Two syntax options are working: $variable or :variable:

# %%
# %sql select top 5 *  from [Sales].[SalesOrderHeader] where CustomerID = :customerid

# %%
# %sql select top 5 * from [Sales].[SalesOrderHeader] where CustomerID  = $customerid

# %%
type(customerid)

# %%
tablename = '[Sales].[SalesOrderHeader]'

# %%
# %sql select top 100 * from $tablename

# %% [markdown]
# # store resultset into variable <a class="anchor" id="dataset"></a>

# %%
db_query = '''
select top 100 * from [Sales].[SalesOrderHeader] '''

# %%
result = %sql $db_query
# Out:
#  * mssql+pyodbc://@dsiwddsn
# Done.

# %%
result[0]

# %% [markdown]
# Print full resultset:

# %%
type(result)
# Out:
# sql.run.ResultSet

# %%
import pandas as pd
res = pd.DataFrame(data = result.dicts())

# %%
res
# Out:
#     SalesOrderID  RevisionNumber  OrderDate    DueDate   ShipDate  Status  \
# 0          43659               8 2011-05-31 2011-06-12 2011-06-07       5
# 1          43660               8 2011-05-31 2011-06-12 2011-06-07       5
# 2          43661               8 2011-05-31 2011-06-12 2011-06-07       5
# 3          43662               8 2011-05-31 2011-06-12 2011-06-07       5
# 4          43663               8 2011-05-31 2011-06-12 2011-06-07       5
# ..           ...             ...        ...        ...        ...     ...
# 95         43754               8 2011-06-14 2011-06-26 2011-06-21       5
# 96         43755               8 2011-06-14 2011-06-26 2011-06-21       5
# 97         43756               8 2011-06-14 2011-06-26 2011-06-21       5
# 98         43757               8 2011-06-14 2011-06-26 2011-06-21       5
# 99         43758               8 2011-06-15 2011-06-27 2011-06-22       5
#
#     OnlineOrderFlag SalesOrderNumber PurchaseOrderNumber   AccountNumber  ...  \
# 0             False          SO43659         PO522145787  10-4020-000676  ...
# 1             False          SO43660       PO18850127500  10-4020-000117  ...
# 2             False          SO43661       PO18473189620  10-4020-000442  ...
# 3             False          SO43662       PO18444174044  10-4020-000227  ...
# 4             False          SO43663       PO18009186470  10-4020-000510  ...
# ..              ...              ...                 ...             ...  ...
# 95             True          SO43754                None  10-4030-027617  ...
# 96             True          SO43755                None  10-4030-027670  ...
# 97             True          SO43756                None  10-4030-019941  ...
# 98             True          SO43757                None  10-4030-011017  ...
# 99             True          SO43758                None  10-4030-027646  ...
#
#     CreditCardID  CreditCardApprovalCode  CurrencyRateID    SubTotal  \
# 0        16281.0           105041Vi84182             NaN  20565.6206
# 1         5618.0           115213Vi29411             NaN   1294.2529
# 2         1346.0             85274Vi6854             4.0  32726.4786
# 3        10456.0           125295Vi53935             4.0  28832.5289
# 4         4322.0            45303Vi22691             NaN    419.4589
# ..           ...                     ...             ...         ...
# 95        9734.0           630188Vi50171             NaN   3578.2700
# 96       14614.0          1030205Vi75785             NaN   3578.2700
# 97        9528.0           830399Vi49119           191.0    699.0982
# 98       12801.0           635102Vi66203           184.0   3374.9900
# 99       17093.0          1230195Vi88773             NaN   3578.2700
#
#        TaxAmt   Freight    TotalDue Comment  \
# 0   1971.5149  616.0984  23153.2339    None
# 1    124.2483   38.8276   1457.3288    None
# 2   3153.7696  985.5530  36865.8012    None
# 3   2775.1646  867.2389  32474.9324    None
# 4     40.2681   12.5838    472.3108    None
# ..        ...       ...         ...     ...
# 95   286.2616   89.4568   3953.9884    None
# 96   286.2616   89.4568   3953.9884    None
# 97    55.9279   17.4775    772.5036    None
# 98   269.9992   84.3748   3729.3640    None
# 99   286.2616   89.4568   3953.9884    None
#
#                                  rowguid ModifiedDate
# 0   79B65321-39CA-4115-9CBA-8FE0903E12E6   2011-06-07
# 1   738DC42D-D03B-48A1-9822-F95A67EA7389   2011-06-07
# 2   D91B9131-18A4-4A11-BC3A-90B6F53E9D74   2011-06-07
# 3   4A1ECFC0-CC3A-4740-B028-1C50BB48711C   2011-06-07
# 4   9B1E7A40-6AE0-4AD3-811C-A64951857C4B   2011-06-07
# ..                                   ...          ...
# 95  86B0C2B9-6ABD-4B69-9C76-2B702B604D77   2011-06-21
# 96  98337979-2598-4E10-8666-4823D1EB0564   2011-06-21
# 97  6D3EE374-D017-4007-9BA3-8966F2B3CD00   2011-06-21
# 98  238FD676-5C9C-44A6-8C10-F890887887B6   2011-06-21
# 99  C54AB7FA-B136-4954-9E52-ED8283E91460   2011-06-22
#
# [100 rows x 26 columns]

# %% [markdown]
# Print second line from resultset ( starts from 0):

# %%
result[10]

# %% [markdown]
# Print one cell from resultset:

# %% [markdown]
# Iterate over the resultset:

# %%
for i in result.dicts():
    print (i['SalesOrderNumber'])

# %% [markdown]
# Look how easy to visualize the query result using pie chart:

# %%
pl = %sql select top 5 SalesPersonID, sum(TotalDue) as SalesAmount from $tablename group by SalesPersonID order by sum(TotalDue) desc;

# %%
pl.bar()

# %% [markdown]
# # pyodbc without Jupyter Magic <a class="anchor" id="pyodbc"></a>

# %%
# example for VM and your personal machine 
import pyodbc
import pandas as pd
conn = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER=localhost;DATABASE=AdventureWorks2019;Trusted_Connection=yes')

# %%
# SQl query
cmd = 'SELECT @@VERSION as info'
# query + pyodbc session -> df
df = pd.read_sql(cmd,conn)
#pandas
df
# Out:
#                                                 info
# 0  Microsoft SQL Server 2019 (RTM-GDR) (KB4583458...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Example of named instance for VM
conn = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER=localhost\SQLEXPRESS;DATABASE=AdventureWorks2019;Trusted_Connection=yes')

# %%
#DSN sample
import pyodbc
import pandas as pd
conn = pyodbc.connect('DSN=dsiwddsn')

# %%
#Connection string for Azure SQL instance
# Let instructor know you need IP address added to firewall rule
import pyodbc
conn = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER=2022dsiwd.database.windows.net;DATABASE=AdventureWorks2019;UID=admin2022dsiwd;PWD=Divergence!2022dsiwd')

# %%
sql = "select top 100 * from [Sales].[SalesOrderHeader] "
data = pd.read_sql(sql,conn)

# %%
data

# %%
type(data)

# %%
import pandas
sql = "SELECT * from [dbo].[titanic2022]"
data = pandas.read_sql(sql,conn2)
data

# %%
foo =data[['Pclass','Survived']].values.tolist()
#.values.tolist()
foo.copy()
