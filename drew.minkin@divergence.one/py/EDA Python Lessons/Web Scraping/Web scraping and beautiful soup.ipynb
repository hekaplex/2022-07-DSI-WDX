# %% [markdown]
# # Lesson 7: Advanced Web Scraping and Data Gathering
# ## Topic 1: Basics of web-scraping using `requests` and `BeautifulSoup` libraries

# %% [markdown]
# ### Import `requests` library

# %%
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\python39\lib\site-packages (4.11.1)
# WARNING: Ignoring invalid distribution -ywin32 (c:\users\andre\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ywin32 (c:\users\andre\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ywin32 (c:\users\andre\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ywin32 (c:\users\andre\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ywin32 (c:\users\andre\appdata\roaming\python\python39\site-packages)
# Requirement already satisfied: soupsieve>1.2 in c:\python39\lib\site-packages (from beautifulsoup4) (2.3.2.post1)
# WARNING: Ignoring invalid distribution -ywin32 (c:\users\andre\appdata\roaming\python\python39\site-packages)
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'c:\python39\python.exe -m pip install --upgrade pip' command.

# %%
import requests

# %% [markdown]
# ### Exercise 1: Use `requests` to get a response from the Wikipedia home page

# %%
# First assign the URL of Wikipedia home page to a string 
wiki_home = "https://en.wikipedia.org/wiki/Main_Page"

# %%
# Use the 'get' method from requests library to get a response
response = requests.get(wiki_home)

# %%
# What is this 'response' object anyway
type(response)
# Out:
# requests.models.Response

# %%
for r in response: print(r)
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Wikipedia, the free encyclo'
# b'pedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":['
# b'"",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May"'
# b',"June","July","August","September","October","November","December"],"wgRequestId":"240ed5bf-6f05-4c48-9b4b-4ca09608373a","wgCSP'
# b'Nonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Main_Page","wgTitl'
# b'e":"Main Page","wgCurRevisionId":1085170884,"wgRevisionId":1085170884,"wgArticleId":15580374,"wgIsArticle":true,"wgIsRedirect":f'
# b'alse,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":[],"wgPageContentLanguage":"en","wgPageContentModel'
# b'":"wikitext","wgRelevantPageName":"Main_Page","wgRelevantArticleId":15580374,"wgIsProbablyEditable":false,"wgRelevantPageIsProba'
# b'blyEditable":false,"wgRestrictionEdit":["sysop"],"wgRestrictionMove":["sysop"],"wgIsMainPage":true,"wgFlaggedRevsParams":{\n"tags'
# b'":{"status":{"levels":1}}},"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFD'
# b'isplayWikibaseDescriptions":{"search":true,"nearby":true,"watchlist":true,"tagline":false},"wgWMESchemaEditAttemptStepOversample'
# b'":false,"wgWMEPageLength":3000,"wgNoticeProject":"wikipedia","wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"w'
# b'gPopupsFlags":10,"wgULSCurrentAutonym":"English","wgEditSubmitButtonLabelPublish":true,"wgCentralAuthMobileDomain":false,"wgULSP'
# b'osition":"interlanguage","wgULSisCompactLinksEnabled":true,"wgWikibaseItemId":"Q5296","GEHomepageSuggestedEditsEnableTopics":tru'
# b'e,"wgGETopicsMatchModeEnabled":false};RLSTATE={"ext.globalCssJs.user.styles":"ready","site.styles":"ready","user.styles":"ready"'
# b',"ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","skins.vector.styles.legacy":"ready","ext.visualEditor.d'
# b'esktopArticleTarget.noscript":"ready","ext.wikimediaBadges":"ready","ext.uls.interlanguage":"ready"\n};RLPAGEMODULES=["site","med'
# b'iawiki.page.ready","skins.vector.legacy.js","mmv.head","mmv.bootstrap.autostart","ext.visualEditor.desktopArticleTarget.init","e'
# b'xt.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.cx.eventlogging.campaigns","e'
# b'xt.centralNotice.geoIP","ext.centralNotice.startUp","ext.gadget.ReferenceTooltips","ext.gadget.charinsert","ext.gadget.extra-too'
# b'lbar-buttons","ext.gadget.refToolbar","ext.gadget.switcher","ext.centralauth.centralautologin","ext.popups","ext.uls.interface",'
# b'"ext.growthExperiments.SuggestedEditSession"];</script>\n<script>(RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.o'
# b'ptions@12s5i",function($,jQuery,require,module){mw.user.tokens.set({"patrolToken":"+\\\\","watchToken":"+\\\\","csrfToken":"+\\\\"});}'
# b');});</script>\n<link rel="stylesheet" href="/w/load.php?lang=en&amp;modules=ext.uls.interlanguage%7Cext.visualEditor.desktopArti'
# b'cleTarget.noscript%7Cext.wikimediaBadges%7Cskins.vector.styles.legacy&amp;only=styles&amp;skin=vector"/>\n<script async="" src="/'
# b'w/load.php?lang=en&amp;modules=startup&amp;only=scripts&amp;raw=1&amp;skin=vector"></script>\n<meta name="ResourceLoaderDynamicSt'
# b'yles" content=""/>\n<link rel="stylesheet" href="/w/load.php?lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector"/>\n<'
# b'meta name="generator" content="MediaWiki 1.39.0-wmf.15"/>\n<meta name="referrer" content="origin"/>\n<meta name="referrer" content'
# b'="origin-when-crossorigin"/>\n<meta name="referrer" content="origin-when-cross-origin"/>\n<meta name="format-detection" content="t'
# b'elephone=no"/>\n<meta property="og:image" content="https://upload.wikimedia.org/wikipedia/commons/thumb/3/3d/Tower_House%2C_Kensi'
# b'ngton%2C_January_2015_03.jpg/1200px-Tower_House%2C_Kensington%2C_January_2015_03.jpg"/>\n<meta property="og:image:width" content='
# b'"1200"/>\n<meta property="og:image:height" content="1600"/>\n<meta property="og:image" content="https://upload.wikimedia.org/wikip'
# b'edia/commons/thumb/3/3d/Tower_House%2C_Kensington%2C_January_2015_03.jpg/800px-Tower_House%2C_Kensington%2C_January_2015_03.jpg"'
# b'/>\n<meta property="og:image:width" content="800"/>\n<meta property="og:image:height" content="1067"/>\n<meta property="og:image" c'
# b'ontent="https://upload.wikimedia.org/wikipedia/commons/thumb/3/3d/Tower_House%2C_Kensington%2C_January_2015_03.jpg/640px-Tower_H'
# b'ouse%2C_Kensington%2C_January_2015_03.jpg"/>\n<meta property="og:image:width" content="640"/>\n<meta property="og:image:height" co'
# b'ntent="853"/>\n<meta property="og:title" content="Wikipedia, the free encyclopedia"/>\n<meta property="og:type" content="website"/'
# b'>\n<link rel="preconnect" href="//upload.wikimedia.org"/>\n<link rel="alternate" media="only screen and (max-width: 720px)" href="'
# b'//en.m.wikipedia.org/wiki/Main_Page"/>\n<link rel="alternate" type="application/atom+xml" title="Wikipedia picture of the day fee'
# b'd" href="/w/api.php?action=featuredfeed&amp;feed=potd&amp;feedformat=atom"/>\n<link rel="alternate" type="application/atom+xml" t'
# b'itle="Wikipedia featured articles feed" href="/w/api.php?action=featuredfeed&amp;feed=featured&amp;feedformat=atom"/>\n<link rel='
# b'"alternate" type="application/atom+xml" title="Wikipedia &quot;On this day...&quot; feed" href="/w/api.php?action=featuredfeed&a'
# b'mp;feed=onthisday&amp;feedformat=atom"/>\n<link rel="apple-touch-icon" href="/static/apple-touch/wikipedia.png"/>\n<link rel="shor'
# b'tcut icon" href="/static/favicon/wikipedia.ico"/>\n<link rel="search" type="application/opensearchdescription+xml" href="/w/opens'
# b'earch_desc.php" title="Wikipedia (en)"/>\n<link rel="EditURI" type="application/rsd+xml" href="//en.wikipedia.org/w/api.php?actio'
# b'n=rsd"/>\n<link rel="license" href="https://creativecommons.org/licenses/by-sa/3.0/"/>\n<link rel="canonical" href="https://en.wik'
# b'ipedia.org/wiki/Main_Page"/>\n<link rel="dns-prefetch" href="//meta.wikimedia.org" />\n<link rel="dns-prefetch" href="//login.wiki'
# b'media.org"/>\n</head>\n<body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject page-Main_Page rootpage-Main_Page '
# b'skin-vector action-view skin-vector-legacy"><div id="mw-page-base" class="noprint"></div>\n<div id="mw-head-base" class="noprint"'
# b'></div>\n<div id="content" class="mw-body" role="main">\n\t<a id="top"></a>\n\t<div id="siteNotice"><!-- CentralNotice --></div>\n\t<di'
# b'v class="mw-indicators">\n\t</div>\n\t<h1 id="firstHeading" class="firstHeading mw-first-heading" style="display: none">Main Page</h'
# b'1>\n\t<div id="bodyContent" class="vector-body">\n\t\t<div id="siteSub" class="noprint">From Wikipedia, the free encyclopedia</div>\n\t'
# b'\t<div id="contentSub"></div>\n\t\t<div id="contentSub2"></div>\n\t\t\n\t\t<div id="jump-to-nav"></div>\n\t\t<a class="mw-jump-link" href="#m'
# b'w-head">Jump to navigation</a>\n\t\t<a class="mw-jump-link" href="#searchInput">Jump to search</a>\n\t\t<div id="mw-content-text" clas'
# b's="mw-body-content mw-content-ltr" lang="en" dir="ltr"><div class="mw-parser-output"><style data-mw-deduplicate="TemplateStyles:'
# b'r1087520986">.mw-parser-output #mp-topbanner{box-sizing:border-box;border-color:#ddd;background-color:#f9f9f9}.mw-parser-output '
# b'.mp-bordered,.mw-parser-output .mp-h2,body.skin-timeless .mw-parser-output .mp-h2{border-width:1px;border-style:solid}.mw-parser'
# b'-output #mp-topbanner,.mw-parser-output .mp-h2,.mw-parser-output #mp-left{color:#000}.mw-parser-output #mp-welcomecount{margin:0'
# b'.4em;text-align:center}.mw-parser-output #mp-welcome{font-size:162%;padding:0.1em}.mw-parser-output #mp-welcome h1{font-size:inh'
# b'erit;font-family:inherit;display:inline;border:none}.mw-parser-output #mp-welcome h1::after{content:none}.mw-parser-output #mp-f'
# b'ree{font-size:95%}.mw-parser-output #articlecount{font-size:85%}.mw-parser-output #mp-banner{margin-top:4px;padding:0.5em;backgr'
# b'ound-color:#fffaf5;border-color:#f2e0ce}.mw-parser-output .mp-h2,body.skin-timeless .mw-parser-output .mp-h2{margin:0.5em;paddin'
# b'g:0.2em 0.4em;font-size:120%;font-weight:bold;font-family:inherit}.mw-parser-output h2.mp-h2::after{border:none}.mw-parser-outpu'
# b't .mp-later{font-size:85%;font-weight:normal}.mw-parser-output #mp-upper{width:100%;margin-top:4px;margin-bottom:0;border-spacin'
# b'g:0;border-collapse:separate}.mw-parser-output #mp-upper .mid-table{border-color:transparent}.mw-parser-output #mp-left{width:55'
# b'%;border-color:#cef2e0;background:#f5fffa}.mw-parser-output #mp-right{width:45%;border-color:#cedff2;background:#f5faff}.mw-pars'
# b'er-output #mp-left,.mw-parser-output #mp-right{padding:0;vertical-align:top}.mw-parser-output #mp-left .mp-h2{background:#cef2e0'
# b';border-color:#a3bfb1}.mw-parser-output #mp-right .mp-h2{background:#cedff2;border-color:#a3b0bf}.mw-parser-output #mp-tfa,.mw-p'
# b'arser-output #mp-dyk,.mw-parser-output #mp-itn,.mw-parser-output #mp-otd,.mw-parser-output #mp-other-lower>div{padding:0.1em 0.6'
# b'em}.mw-parser-output #mp-dyk-h2,.mw-parser-output #mp-otd-h2{clear:both}.mw-parser-output #mp-middle{margin-top:4px;border-color'
# b':#f2cedd;background:#fff5fa}.mw-parser-output #mp-middle,.mw-parser-output #mp-lower,.mw-parser-output #mp-other-lower{overflow:'
# b'auto}.mw-parser-output #mp-tfl-h2{background:#f2cedd;border-color:#bfa3af}.mw-parser-output #mp-tfl{padding:0.3em 0.7em}.mw-pars'
# b'er-output #mp-lower{margin-top:4px;border-color:#ddcef2;background:#faf5ff}.mw-parser-output #mp-tfp-h2{background:#ddcef2;borde'
# b'r-color:#afa3bf}.mw-parser-output #mp-tfp{margin:0.1em 0.4em 0.6em}.mw-parser-output #mp-other-lower{padding:0;border-color:#e2e'
# b'2e2;margin-top:4px}.mw-parser-output #mp-dyk,.mw-parser-output #mp-otd,.mw-parser-output #mp-other-lower{padding-bottom:0.5em}.m'
# b'w-parser-output #mp-other-lower .mp-h2{background:#eee;border-color:#ddd;color:#222}@media(max-width:875px){body.skin--responsiv'
# b'e .mw-parser-output table,body.skin--responsive .mw-parser-output tr,body.skin--responsive .mw-parser-output td,body.skin--respo'
# b'nsive .mw-parser-output tbody{display:block!important;width:100%!important;box-sizing:border-box}body.skin--responsive .mw-parse'
# b'r-output #mp-tfp tr:first-child td:first-child a{text-align:center;display:table;margin:0 auto}}.mw-parser-output div.hlist.inli'
# b'ne ul,.mw-parser-output div.hlist.inline li,.mw-parser-output div.hlist.inline{display:inline}</style>\n<div id="mp-topbanner" cl'
# b'ass="mp-bordered">\n<div id="mp-welcomecount">\n<div id="mp-welcome"><h1><span class="mw-headline" id="Welcome_to_Wikipedia">Welco'
# b'me to <a href="/wiki/Wikipedia" title="Wikipedia">Wikipedia</a></span></h1>,</div>\n<div id="mp-free">the <a href="/wiki/Free_con'
# b'tent" title="Free content">free</a> <a href="/wiki/Encyclopedia" title="Encyclopedia">encyclopedia</a> that <a href="/wiki/Help:'
# b'Introduction_to_Wikipedia" title="Help:Introduction to Wikipedia">anyone can edit</a>.</div>\n<div id="articlecount"><a href="/wi'
# b'ki/Special:Statistics" title="Special:Statistics">6,512,161</a> articles in <a href="/wiki/English_language" title="English lang'
# b'uage">English</a></div>\n</div>\n</div>\n<table role="presentation" id="mp-upper">\n<tbody><tr>\n<td id="mp-left" class="MainPageBG m'
# b'p-bordered">\n<h2 id="mp-tfa-h2" class="mp-h2"><span id="From_today.27s_featured_article"></span><span class="mw-headline" id="Fr'
# b'om_today\'s_featured_article">From today\'s featured article</span></h2>\n<div id="mp-tfa"><div id="mp-tfa-img" style="float: left;'
# b' margin: 0.5em 0.9em 0.4em 0em;">\n<div class="thumbinner mp-thumb" style="background: transparent; border: none; padding: 0; max'
# b'-width: 121px;">\n<a href="/wiki/File:Tower_House,_Kensington,_January_2015_03.jpg" class="image" title="The Tower House"><img al'
# b't="The Tower House" src="//upload.wikimedia.org/wikipedia/commons/thumb/3/3d/Tower_House%2C_Kensington%2C_January_2015_03.jpg/12'
# b'1px-Tower_House%2C_Kensington%2C_January_2015_03.jpg" decoding="async" width="121" height="161" srcset="//upload.wikimedia.org/w'
# b'ikipedia/commons/thumb/3/3d/Tower_House%2C_Kensington%2C_January_2015_03.jpg/182px-Tower_House%2C_Kensington%2C_January_2015_03.'
# b'jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/3/3d/Tower_House%2C_Kensington%2C_January_2015_03.jpg/242px-Tower_House'
# b'%2C_Kensington%2C_January_2015_03.jpg 2x" data-file-width="3456" data-file-height="4608" /></a></div>\n</div>\n<p><b><a href="/wik'
# b'i/The_Tower_House" title="The Tower House">The Tower House</a></b>, in the district of <a href="/wiki/Holland_Park" title="Holla'
# b'nd Park">Holland Park</a> in <a href="/wiki/Royal_Borough_of_Kensington_and_Chelsea" title="Royal Borough of Kensington and Chel'
# b'sea">Kensington and Chelsea</a>, London, is a late Victorian <a href="/wiki/Townhouse" title="Townhouse">townhouse</a> built bet'
# b'ween 1875 and 1881 by the architect and designer <a href="/wiki/William_Burges" title="William Burges">William Burges</a> as his'
# b' personal residence. Designed in the French <a href="/wiki/Gothic_Revival_architecture" title="Gothic Revival architecture">Goth'
# b"ic Revival</a> style, it echoes elements of Burges's earlier work. The house was built of red brick by the Ashby Brothers, with "
# b"a distinctive cylindrical tower and conical roof. The interior was decorated by members of Burges's long-standing team of crafts"
# b'men including <a href="/wiki/Thomas_Nicholls_(sculptor)" title="Thomas Nicholls (sculptor)">Thomas Nicholls</a> and <a href="/wi'
# b'ki/Henry_Stacy_Marks" title="Henry Stacy Marks">Henry Stacy Marks</a>. The house retains most of its internal structural decorat'
# b'ion, but much of the furniture, fittings and contents that Burges designed have been dispersed. Many items, including the <a hre'
# b'f="/wiki/Great_Bookcase" title="Great Bookcase">Great Bookcase</a>, the <a href="/wiki/Zodiac_settle" title="Zodiac settle">Zodi'
# b'ac settle</a>, the <a href="/wiki/Golden_Bed" title="Golden Bed">Golden Bed</a> and the <a href="/wiki/The_Red_Bed" title="The R'
# b'ed Bed">Red Bed</a>, are now in institutions such as <a href="/wiki/The_Higgins_Art_Gallery_%26_Museum" title="The Higgins Art G'
# b'allery &amp; Museum">The Higgins Bedford</a> and the <a href="/wiki/Victoria_and_Albert_Museum" title="Victoria and Albert Museu'
# b'm">Victoria and Albert Museum</a>. The house was designated a <a href="/wiki/Listed_building#Categories_of_listed_building" titl'
# b'e="Listed building">Grade&#160;I listed building</a> in 1949. (<b><a href="/wiki/The_Tower_House" title="The Tower House">Full&#'
# b'160;article...</a></b>)\n</p>\n<div class="tfa-recent" style="text-align: right;">\nRecently featured: <div class="hlist hlist-sepa'
# b'rated inline">\n<ul><li><a href="/wiki/Hurricane_Leslie_(2018)" title="Hurricane Leslie (2018)">Hurricane Leslie (2018)</a></li>\n'
# b'<li><i><a href="/wiki/Mosasaurus" title="Mosasaurus">Mosasaurus</a></i></li>\n<li><a href="/wiki/On_the_Job_(2013_film)" title="O'
# b'n the Job (2013 film)"><i>On the Job</i> (2013 film)</a></li></ul>\n</div></div>\n<div class="hlist hlist-separated tfa-footer nop'
# b'rint" style="text-align:right;">\n<ul><li><b><a href="/wiki/Wikipedia:Today%27s_featured_article/June_2022" title="Wikipedia:Toda'
# b'y&#39;s featured article/June 2022">Archive</a></b></li>\n<li><b><a href="https://lists.wikimedia.org/postorius/lists/daily-artic'
# b'le-l.lists.wikimedia.org/" class="extiw" title="mail:daily-article-l">By email</a></b></li>\n<li><b><a href="/wiki/Wikipedia:Feat'
# b'ured_articles" title="Wikipedia:Featured articles">More featured articles</a></b></li></ul>\n</div></div>\n<h2 id="mp-dyk-h2" clas'
# b's="mp-h2"><span class="mw-headline" id="Did_you_know_...">Did you know&#160;...</span></h2>\n<div id="mp-dyk">\n<div class="dyk-im'
# b'g" style="float: right; margin-left: 0.5em;">\n<div class="thumbinner mp-thumb" style="background: transparent; border: none; pad'
# b'ding: 0; max-width: 156px;">\n<a href="/wiki/File:Levitan_Evening_bells_1892.jpg" class="image" title="Evening Bells by Isaac Lev'
# b'itan"><img alt="Evening Bells by Isaac Levitan" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/15/Levitan_Evening_bells_1'
# b'892.jpg/156px-Levitan_Evening_bells_1892.jpg" decoding="async" width="156" height="125" srcset="//upload.wikimedia.org/wikipedia'
# b'/commons/thumb/1/15/Levitan_Evening_bells_1892.jpg/234px-Levitan_Evening_bells_1892.jpg 1.5x, //upload.wikimedia.org/wikipedia/c'
# b'ommons/thumb/1/15/Levitan_Evening_bells_1892.jpg/312px-Levitan_Evening_bells_1892.jpg 2x" data-file-width="1999" data-file-heigh'
# b't="1600" /></a><div class="thumbcaption" style="padding: 0.25em 0; word-wrap: break-word;"><i>Evening Bells</i> by Isaac Levitan'
# b'</div></div>\n</div>\n<ul><li>... that <a href="/wiki/Isaac_Levitan" title="Isaac Levitan">Isaac Levitan</a> was inspired to paint'
# b' <i><b><a href="/wiki/Evening_Bells_(painting)" title="Evening Bells (painting)">Evening Bells</a></b></i> <i>(pictured)</i> whe'
# b'n he came across a small monastery in a remote village?</li>\n<li>... that <b><a href="/wiki/Sam_Smith_(basketball,_born_1943)" t'
# b'itle="Sam Smith (basketball, born 1943)">Sam Smith</a></b> left the <a href="/wiki/University_of_Louisville" title="University o'
# b'f Louisville">University of Louisville</a> after being found to be academically ineligible for  <a href="/wiki/Louisville_Cardin'
# b'als_men%27s_basketball" title="Louisville Cardinals men&#39;s basketball">its basketball team</a>, claiming the school was "too '
# b'big for him"?</li>\n<li>... that the adoption of the <b><a href="/wiki/Declaration_of_Independence_of_Azerbaijan" title="Declarat'
# b'ion of Independence of Azerbaijan">Declaration of Independence of Azerbaijan</a></b> made the <a href="/wiki/Azerbaijan_Democrat'
# b'ic_Republic" title="Azerbaijan Democratic Republic">Azerbaijan Democratic Republic</a> the first successful republic in the <a h'
# b'ref="/wiki/Muslim_world" title="Muslim world">Muslim world</a>?</li>\n<li>... that <b><a href="/wiki/Arnold_Blackner" title="Arno'
# b'ld Blackner">Arnold Blackner</a></b> was said to be the first person to sing over 3,000 miles on the telephone?</li>\n<li>... tha'
# b't the literary movement of <i><b><a href="/wiki/Cr%C3%A9olie" title="Cr\xc3\xa9olie">cr\xc3\xa9olie</a></b></i> tries to integrate the ident'
# b'ity of <a href="/wiki/R%C3%A9union" title="R\xc3\xa9union">R\xc3\xa9union</a> with France?</li>\n<li>... that  the <i><b><a href="/wiki/Four-'
# b'Track_News" title="Four-Track News">Four-Track News</a></b></i> is not news about the <a href="/wiki/Stereo-Pak" title="Stereo-P'
# b'ak">car music cassettes</a> of the 1950s, but an illustrated magazine of the early 1900s on travel and education put out by the '
# b'<a href="/wiki/New_York_Central_Railroad" title="New York Central Railroad">New York Central Railroad</a>?</li>\n<li>... that rec'
# b'ords of <b><a href="/wiki/Acoutsina" title="Acoutsina">Acoutsina</a></b><span class="nowrap">&#39;s</span> captivity allow histo'
# b'rians to analyse the eighteenth century French-<a href="/wiki/Eskimo" title="Eskimo">Eskimo</a> relationship?</li>\n<li>... that '
# b'<a href="/wiki/Midwest_Communications" title="Midwest Communications">a regional radio group with 75 stations</a> started with a'
# b' "<b><a href="/wiki/WRIG" title="WRIG">Big Wrig</a></b>"?</li></ul>\n<div class="hlist hlist-separated dyk-footer noprint" style='
# b'"margin-top: 0.5em; text-align: right;">\n<ul><li><b><a href="/wiki/Wikipedia:Recent_additions" title="Wikipedia:Recent additions'
# b'">Archive</a></b></li>\n<li><b><a href="/wiki/Help:Your_first_article" title="Help:Your first article">Start a new article</a></b'
# b'></li>\n<li><b><a href="/wiki/Template_talk:Did_you_know" title="Template talk:Did you know">Nominate an article</a></b></li></ul'
# b'>\n</div>\n</div>\n</td>\n<td class="mp-bordered mid-table">\n</td>\n<td id="mp-right" class="MainPageBG mp-bordered">\n<h2 id="mp-itn-'
# b'h2" class="mp-h2"><span class="mw-headline" id="In_the_news">In the news</span></h2>\n<div id="mp-itn"><style data-mw-deduplicate'
# b'="TemplateStyles:r1053378754">.mw-parser-output .itn-img{float:right;margin-left:0.5em;margin-top:0.2em}</style><div role="figur'
# b'e" class="itn-img">\n<div class="thumbinner mp-thumb" style="background: transparent; border: none; padding: 0; max-width: 140px;'
# b'">\n<a href="/wiki/File:Jeanine_%C3%81%C3%B1ez_at_the_Miraflores_Women%27s_Penitentiary._March_2021,_Plurinational_Legislative_As'
# b'sembly,_La_Paz_(51961522989)_(cropped_680%C3%97720).jpg" class="image" title="Jeanine \xc3\x81\xc3\xb1ez in March 2021"><img alt="Jeanine \xc3\x81'
# b'\xc3\xb1ez in March 2021" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/1f/Jeanine_%C3%81%C3%B1ez_at_the_Miraflores_Women%27s_'
# b'Penitentiary._March_2021%2C_Plurinational_Legislative_Assembly%2C_La_Paz_%2851961522989%29_%28cropped_680%C3%97720%29.jpg/140px-'
# b'Jeanine_%C3%81%C3%B1ez_at_the_Miraflores_Women%27s_Penitentiary._March_2021%2C_Plurinational_Legislative_Assembly%2C_La_Paz_%285'
# b'1961522989%29_%28cropped_680%C3%97720%29.jpg" decoding="async" width="140" height="148" srcset="//upload.wikimedia.org/wikipedia'
# b'/commons/thumb/1/1f/Jeanine_%C3%81%C3%B1ez_at_the_Miraflores_Women%27s_Penitentiary._March_2021%2C_Plurinational_Legislative_Ass'
# b'embly%2C_La_Paz_%2851961522989%29_%28cropped_680%C3%97720%29.jpg/210px-Jeanine_%C3%81%C3%B1ez_at_the_Miraflores_Women%27s_Penite'
# b'ntiary._March_2021%2C_Plurinational_Legislative_Assembly%2C_La_Paz_%2851961522989%29_%28cropped_680%C3%97720%29.jpg 1.5x, //uplo'
# b'ad.wikimedia.org/wikipedia/commons/thumb/1/1f/Jeanine_%C3%81%C3%B1ez_at_the_Miraflores_Women%27s_Penitentiary._March_2021%2C_Plu'
# b'rinational_Legislative_Assembly%2C_La_Paz_%2851961522989%29_%28cropped_680%C3%97720%29.jpg/280px-Jeanine_%C3%81%C3%B1ez_at_the_M'
# b'iraflores_Women%27s_Penitentiary._March_2021%2C_Plurinational_Legislative_Assembly%2C_La_Paz_%2851961522989%29_%28cropped_680%C3'
# b'%97720%29.jpg 2x" data-file-width="680" data-file-height="720" /></a><div class="thumbcaption" style="padding: 0.25em 0; word-wr'
# b'ap: break-word; text-align: left;">Jeanine \xc3\x81\xc3\xb1ez</div></div>\n</div>\n<ul><li>Former Bolivian president <b><a href="/wiki/Jeanine'
# b'_%C3%81%C3%B1ez" title="Jeanine \xc3\x81\xc3\xb1ez">Jeanine \xc3\x81\xc3\xb1ez</a></b> <i>(pictured)</i> is sentenced to ten years in prison on charges '
# b'related to her succession to office during the <a href="/wiki/2019_Bolivian_political_crisis" title="2019 Bolivian political cri'
# b'sis">2019 political crisis</a>.</li>\n<li>In Nigeria, at least 40 people are killed in <b><a href="/wiki/Owo_church_attack" title'
# b'="Owo church attack">an attack</a></b> at a <a href="/wiki/Catholic_Church_in_Nigeria" title="Catholic Church in Nigeria">Cathol'
# b'ic church</a> in <a href="/wiki/Owo" title="Owo">Owo</a>, <a href="/wiki/Ondo_State" title="Ondo State">Ondo State</a>.</li>\n<li'
# b'><b><a href="/wiki/2022_Sitakunda_fire_and_explosions" title="2022 Sitakunda fire and explosions">A fire and explosions</a></b> '
# b'at a storage depot in <a href="/wiki/Sitakunda_Upazila" title="Sitakunda Upazila">Sitakunda</a>, Bangladesh, kill at least 41 pe'
# b'ople and injure more than 450 others.</li>\n<li>The <a href="/wiki/Commonwealth_of_Nations" title="Commonwealth of Nations">Commo'
# b'n&#173;wealth of Nations</a> celebrates <b><a href="/wiki/Platinum_Jubilee_of_Elizabeth_II" title="Platinum Jubilee of Elizabeth'
# b' II">the Platinum Jubilee</a></b> of <b><a href="/wiki/Elizabeth_II" title="Elizabeth II">Elizabeth<span class="nowrap">&#160;</'
# b'span>II</a></b>.</li></ul>\n<div class="itn-footer" style="margin-top: 0.5em;">\n<div><b><a href="/wiki/Portal:Current_events" tit'
# b'le="Portal:Current events">Ongoing</a></b>: <div class="hlist hlist-separated inline">\n<ul><li><a href="/wiki/COVID-19_pandemic"'
# b' title="COVID-19 pandemic">COVID-19 pandemic</a></li>\n<li><a href="/wiki/2022_Russian_invasion_of_Ukraine" title="2022 Russian i'
# b'nvasion of Ukraine">Russian invasion of Ukraine</a></li></ul></div></div>\n<div><b><a href="/wiki/Deaths_in_2022" title="Deaths i'
# b'n 2022">Recent deaths</a></b>&#58; <div class="hlist hlist-separated inline">\n<ul><li><a href="/wiki/Christof_May" title="Christ'
# b'of May">Christof May</a></li>\n<li><a href="/wiki/Julee_Cruise" title="Julee Cruise">Julee Cruise</a></li>\n<li><a href="/wiki/Era'
# b'smus_Sch%C3%B6fer" title="Erasmus Sch\xc3\xb6fer">Erasmus Sch\xc3\xb6fer</a></li>\n<li><a href="/wiki/Paula_Rego" title="Paula Rego">Paula Re'
# b'go</a></li>\n<li><a href="/wiki/Christopher_Pratt" title="Christopher Pratt">Christopher Pratt</a></li>\n<li><span class="nowrap">'
# b'<a href="/wiki/Dorothy_E._Smith" title="Dorothy E. Smith">Dorothy E. Smith</a></span></li></ul></div></div></div>\n<div class="hl'
# b'ist hlist-separated itn-footer noprint" style="text-align:right;">\n<ul><li><b><a href="/wiki/Wikipedia:In_the_news/Candidates" t'
# b'itle="Wikipedia:In the news/Candidates">Nominate an article</a></b></li></ul>\n</div></div>\n<h2 id="mp-otd-h2" class="mp-h2"><spa'
# b'n class="mw-headline" id="On_this_day">On this day</span></h2>\n<div id="mp-otd">\n<p><b><a href="/wiki/June_12" title="June 12">J'
# b'une 12</a></b>: <i><b><a href="/wiki/Dia_dos_Namorados" title="Dia dos Namorados">Dia dos Namorados</a></b></i> in Brazil; <b><a'
# b' href="/wiki/Independence_Day_(Philippines)" title="Independence Day (Philippines)">Independence Day</a></b> in the Philippines '
# b'(<a href="/wiki/1898" title="1898">1898</a>); <b><a href="/wiki/Loving_Day" title="Loving Day">Loving Day</a></b> in the United '
# b'States (<a href="/wiki/1967" title="1967">1967</a>)\n</p>\n<div style="float:right;margin-left:0.5em;" id="mp-otd-img">\n<div class'
# b'="thumbinner mp-thumb" style="background: transparent; border: none; padding: 0; max-width: 125px;">\n<a href="/wiki/File:AnneFra'
# b'nkSchoolPhoto_4-5_(cropped).jpg" class="image" title="Anne Frank"><img alt="Anne Frank" src="//upload.wikimedia.org/wikipedia/co'
# b'mmons/thumb/9/9e/AnneFrankSchoolPhoto_4-5_%28cropped%29.jpg/125px-AnneFrankSchoolPhoto_4-5_%28cropped%29.jpg" decoding="async" w'
# b'idth="125" height="156" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/9/9e/AnneFrankSchoolPhoto_4-5_%28cropped%29.jpg/1'
# b'88px-AnneFrankSchoolPhoto_4-5_%28cropped%29.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/9/9e/AnneFrankSchoolPhoto_4'
# b'-5_%28cropped%29.jpg/250px-AnneFrankSchoolPhoto_4-5_%28cropped%29.jpg 2x" data-file-width="345" data-file-height="430" /></a><di'
# b'v class="thumbcaption" style="padding: 0.25em 0; word-wrap: break-word;">Anne Frank</div></div>\n</div>\n<ul><li><a href="/wiki/17'
# b'98" title="1798">1798</a> \xe2\x80\x93 Following the successful <b><a href="/wiki/French_invasion_of_Malta" title="French invasion of Mal'
# b'ta">French invasion of Malta</a></b>, the <a href="/wiki/Knights_Hospitaller" title="Knights Hospitaller">Knights Hospitaller</a'
# b'> surrendered Malta to <a href="/wiki/Napoleon" title="Napoleon">Napoleon</a>, initiating <a href="/wiki/French_occupation_of_Ma'
# b'lta" title="French occupation of Malta">two years of occupation</a>.</li>\n<li><a href="/wiki/1899" title="1899">1899</a> \xe2\x80\x93 The'
# b' <b><a href="/wiki/1899_New_Richmond_tornado" title="1899 New Richmond tornado">New Richmond tornado</a></b> killed 117 people a'
# b'nd injured 125 others in the <a href="/wiki/Upper_Midwest" title="Upper Midwest">Upper Midwest</a> region of the United States.<'
# b'/li>\n<li><a href="/wiki/1942" title="1942">1942</a> \xe2\x80\x93 On her thirteenth birthday, <b><a href="/wiki/Anne_Frank" title="Anne Fr'
# b'ank">Anne Frank</a></b> <i>(pictured)</i> began keeping <b><a href="/wiki/The_Diary_of_a_Young_Girl" title="The Diary of a Young'
# b' Girl">a diary</a></b> during the <a href="/wiki/Netherlands_in_World_War_II" title="Netherlands in World War II">Nazi occupatio'
# b'n of the Netherlands</a> in World War&#160;II.</li>\n<li><a href="/wiki/1991" title="1991">1991</a> \xe2\x80\x93 More than 150 <a href="/w'
# b'iki/Sri_Lankan_Tamils" title="Sri Lankan Tamils">Sri Lankan Tamil</a> civilians <b><a href="/wiki/1991_Kokkadichcholai_massacre"'
# b' title="1991 Kokkadichcholai massacre">were massacred</a></b> by members of the military in the village of <a href="/wiki/Kokkad'
# b'ichcholai" title="Kokkadichcholai">Kokkadichcholai</a>.</li></ul>\n<div class="hlist hlist-separated" style="margin-top: 0.5em;">'
# b'<ul><li><b><a href="/wiki/Thomas_Farnaby" title="Thomas Farnaby">Thomas Farnaby</a></b>  (<abbr title="died">d.</abbr>&#160;1647'
# b')</li><li><b><a href="/wiki/Egwale_Seyon" title="Egwale Seyon">Egwale Seyon</a></b>  (<abbr title="died">d.</abbr>&#160;1818)</l'
# b'i><li><b><a href="/wiki/Javed_Miandad" title="Javed Miandad">Javed Miandad</a></b>  (<abbr title="born">b.</abbr>&#160;1957)</li'
# b'></ul></div>\n<div style="margin-top:0.5em;">\nMore anniversaries: <div class="hlist hlist-separated inline nowraplinks">\n<ul><li>'
# b'<a href="/wiki/June_11" title="June 11">June 11</a></li>\n<li><b><a href="/wiki/June_12" title="June 12">June 12</a></b></li>\n<li'
# b'><a href="/wiki/June_13" title="June 13">June 13</a></li></ul>\n</div></div>\n<div class="hlist hlist-separated otd-footer noprint'
# b'" style="text-align:right;">\n<ul><li><b><a href="/wiki/Wikipedia:Selected_anniversaries/June" title="Wikipedia:Selected annivers'
# b'aries/June">Archive</a></b></li>\n<li><b><a href="https://lists.wikimedia.org/postorius/lists/daily-article-l.lists.wikimedia.org'
# b'/" class="extiw" title="mail:daily-article-l">By email</a></b></li>\n<li><b><a href="/wiki/List_of_days_of_the_year" title="List '
# b'of days of the year">List of days of the year</a></b></li></ul>\n</div></div>\n</td></tr></tbody></table>\n<div id="mp-lower" class'
# b'="MainPageBG mp-bordered">\n<div id="mp-bottom">\n<h2 id="mp-tfp-h2" class="mp-h2"><span id="Today.27s_featured_picture"></span><s'
# b'pan class="mw-headline" id="Today\'s_featured_picture">Today\'s featured picture</span></h2>\n<div id="mp-tfp">\n<table role="presen'
# b'tation" style="margin:0 3px 3px; width:100%; box-sizing:border-box; text-align:left; background-color:transparent; border-collap'
# b'se:collapse;">\n<tbody><tr>\n<td style="padding:0 0.9em 0 0; width:300px;"><a href="/wiki/File:Fl%C3%A8che_en_feu_-_Spire_on_Fire.'
# b'jpeg" class="image" title="Notre-Dame fire"><img alt="Notre-Dame fire" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/12/'
# b'Fl%C3%A8che_en_feu_-_Spire_on_Fire.jpeg/300px-Fl%C3%A8che_en_feu_-_Spire_on_Fire.jpeg" decoding="async" width="300" height="421"'
# b' srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/12/Fl%C3%A8che_en_feu_-_Spire_on_Fire.jpeg/450px-Fl%C3%A8che_en_feu_-_'
# b'Spire_on_Fire.jpeg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/12/Fl%C3%A8che_en_feu_-_Spire_on_Fire.jpeg/600px-Fl%C3'
# b'%A8che_en_feu_-_Spire_on_Fire.jpeg 2x" data-file-width="3712" data-file-height="5208" /></a>\n</td>\n<td style="padding:0 6px 0 0"'
# b'>\n<p>The <b><a href="/wiki/Notre-Dame_fire" title="Notre-Dame fire">Notre-Dame fire</a></b> broke out in the cathedral of <a hre'
# b'f="/wiki/Notre-Dame_de_Paris" title="Notre-Dame de Paris">Notre-Dame de Paris</a> on 15&#160;April 2019, causing severe damage t'
# b'o <a href="/wiki/Spire_of_Notre-Dame_de_Paris" title="Spire of Notre-Dame de Paris">the building\'s spire</a>, roof, and upper wa'
# b'lls. The fire resulted in the contamination of the site and nearby areas of the city with toxic dust and lead. Investigators bel'
# b'ieved that the fire was caused by a cigarette or an electrical <a href="/wiki/Short_circuit" title="Short circuit">short circuit'
# b"</a>; the prosecutor of Paris found no evidence showing the fire was started deliberately. The cathedral's wooden spire, or <a h"
# b'ref="/wiki/Fl%C3%A8che_(architecture)" title="Fl\xc3\xa8che (architecture)">fl\xc3\xa8che</a>, was built by <a href="/wiki/Eug%C3%A8ne_Violl'
# b'et-le-Duc" title="Eug\xc3\xa8ne Viollet-le-Duc">Eug\xc3\xa8ne Viollet-le-Duc</a> in the <a href="/wiki/Gothic_Revival_architecture" title="G'
# b'othic Revival architecture">Gothic Revival</a> style and installed in 1859, weighing around 250 tons. This photograph, taken dur'
# b'ing the 2019 fire, depicts the spire of Notre-Dame aflame; it collapsed shortly afterwards.\n</p>\n<p style="text-align:left;"><sm'
# b'all>Photograph credit: Guillaume Levrier</small></p>\n<div class="potd-recent" style="text-align:right;">\nRecently featured: <div'
# b' class="hlist hlist-separated inline">\n<ul><li><a href="/wiki/Template:POTD/2022-06-11" title="Template:POTD/2022-06-11">Julia M'
# b'argaret Cameron</a></li>\n<li><a href="/wiki/Template:POTD/2022-06-10" title="Template:POTD/2022-06-10"><i>Sinopterus dongi</i></'
# b'a></li>\n<li><a href="/wiki/Template:POTD/2022-06-09" title="Template:POTD/2022-06-09"><i>The Anatomy Lesson of Dr.&#160;Nicolaes'
# b' Tulp</i></a></li></ul>\n</div></div>\n<div class="hlist hlist-separated potd-footer noprint" style="text-align:right;">\n<ul><li><'
# b'b><a href="/wiki/Wikipedia:Picture_of_the_day/Archive" title="Wikipedia:Picture of the day/Archive">Archive</a></b></li>\n<li><b>'
# b'<a href="/wiki/Wikipedia:Featured_pictures" title="Wikipedia:Featured pictures">More featured pictures</a></b></li></ul>\n</div>\n'
# b'</td></tr></tbody></table></div>\n</div>\n</div>\n<div id="mp-other-lower" class="mp-bordered">\n<h2 id="mp-other" class="mp-h2"><sp'
# b'an class="mw-headline" id="Other_areas_of_Wikipedia">Other areas of Wikipedia</span></h2>\n<div id="mp-other-content">\n<ul><li><b'
# b'><a href="/wiki/Wikipedia:Community_portal" title="Wikipedia:Community portal">Community portal</a></b> \xe2\x80\x93 The central hub for '
# b'editors, with resources, links, tasks, and announcements.</li>\n<li><b><a href="/wiki/Wikipedia:Village_pump" title="Wikipedia:Vi'
# b'llage pump">Village pump</a></b> \xe2\x80\x93 Forum for discussions about Wikipedia itself, including policies and technical issues.</li>'
# b'\n<li><b><a href="/wiki/Wikipedia:News" title="Wikipedia:News">Site news</a></b> \xe2\x80\x93 Sources of news about Wikipedia and the broa'
# b'der Wikimedia movement.</li>\n<li><b><a href="/wiki/Wikipedia:Teahouse" title="Wikipedia:Teahouse">Teahouse</a></b> \xe2\x80\x93 Ask basic'
# b' questions about using or editing Wikipedia.</li>\n<li><b><a href="/wiki/Wikipedia:Help_desk" title="Wikipedia:Help desk">Help de'
# b'sk</a></b> \xe2\x80\x93 Ask questions about using or editing Wikipedia.</li>\n<li><b><a href="/wiki/Wikipedia:Reference_desk" title="Wikip'
# b'edia:Reference desk">Reference desk</a></b> \xe2\x80\x93 Ask research questions about encyclopedic topics.</li>\n<li><b><a href="/wiki/Wik'
# b'ipedia:Contents/Portals" title="Wikipedia:Contents/Portals">Content portals</a></b> \xe2\x80\x93 A unique way to navigate the encyclopedi'
# b'a.</li></ul>\n</div>\n<h2 id="mp-sister" class="mp-h2"><span id="Wikipedia.27s_sister_projects"></span><span class="mw-headline" i'
# b'd="Wikipedia\'s_sister_projects">Wikipedia\'s sister projects</span></h2>\n<div id="mp-sister-content"><style data-mw-deduplicate="'
# b'TemplateStyles:r1007624485">.mw-parser-output #sister-projects-list{display:flex;flex-wrap:wrap}.mw-parser-output #sister-projec'
# b'ts-list li{display:inline-block}.mw-parser-output #sister-projects-list li span{font-weight:bold}.mw-parser-output #sister-proje'
# b'cts-list li>div{display:inline-block;vertical-align:middle;padding:6px 4px}.mw-parser-output #sister-projects-list li>div:first-'
# b'child{text-align:center}@media(min-width:360px){.mw-parser-output #sister-projects-list li{width:33%;min-width:20em;white-space:'
# b'nowrap;flex:1 0 25%}.mw-parser-output #sister-projects-list li>div:first-child{min-width:50px}}</style>\n<p>Wikipedia is written '
# b'by volunteer editors and hosted by the <a href="/wiki/Wikimedia_Foundation" title="Wikimedia Foundation">Wikimedia Foundation</a'
# b'>, a non-profit organization that also hosts a range of other volunteer <a href="https://wikimediafoundation.org/our-work/wikime'
# b'dia-projects/" class="extiw" title="foundationsite:our-work/wikimedia-projects/">projects</a>:\n</p>\n<div class="plainlist">\n<ul '
# b'id="sister-projects-list">\n<li>\n  <div><a href="https://commons.wikimedia.org/wiki/" title="Commons"><img alt="Commons logo" src'
# b'="//upload.wikimedia.org/wikipedia/en/thumb/4/4a/Commons-logo.svg/31px-Commons-logo.svg.png" decoding="async" width="31" height='
# b'"42" srcset="//upload.wikimedia.org/wikipedia/en/thumb/4/4a/Commons-logo.svg/47px-Commons-logo.svg.png 1.5x, //upload.wikimedia.'
# b'org/wikipedia/en/thumb/4/4a/Commons-logo.svg/62px-Commons-logo.svg.png 2x" data-file-width="1024" data-file-height="1376" /></a>'
# b'</div>\n  <div><span><a href="https://commons.wikimedia.org/wiki/" class="extiw" title="c:">Commons</a></span><br />Free media re'
# b'pository</div>\n</li>\n<li>\n  <div><a href="https://www.mediawiki.org/wiki/" title="MediaWiki"><img alt="MediaWiki logo" src="//up'
# b'load.wikimedia.org/wikipedia/commons/thumb/a/a6/MediaWiki-2020-icon.svg/35px-MediaWiki-2020-icon.svg.png" decoding="async" width'
# b'="35" height="35" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/a6/MediaWiki-2020-icon.svg/53px-MediaWiki-2020-icon.s'
# b'vg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/a6/MediaWiki-2020-icon.svg/70px-MediaWiki-2020-icon.svg.png 2x" da'
# b'ta-file-width="100" data-file-height="100" /></a></div>\n  <div><span><a href="https://www.mediawiki.org/wiki/" class="extiw" tit'
# b'le="mw:">MediaWiki</a></span><br />Wiki software development</div>\n</li>\n<li>\n  <div><a href="https://meta.wikimedia.org/wiki/" '
# b'title="Meta-Wiki"><img alt="Meta-Wiki logo" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/75/Wikimedia_Community_Logo.sv'
# b'g/35px-Wikimedia_Community_Logo.svg.png" decoding="async" width="35" height="35" srcset="//upload.wikimedia.org/wikipedia/common'
# b's/thumb/7/75/Wikimedia_Community_Logo.svg/53px-Wikimedia_Community_Logo.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/t'
# b'humb/7/75/Wikimedia_Community_Logo.svg/70px-Wikimedia_Community_Logo.svg.png 2x" data-file-width="900" data-file-height="900" />'
# b'</a></div>\n  <div><span><a href="https://meta.wikimedia.org/wiki/" class="extiw" title="m:">Meta-Wiki</a></span><br />Wikimedia '
# b'project coordination</div>\n</li>\n<li>\n  <div><a href="https://en.wikibooks.org/wiki/" title="Wikibooks"><img alt="Wikibooks logo'
# b'" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Wikibooks-logo.svg/35px-Wikibooks-logo.svg.png" decoding="async" widt'
# b'h="35" height="35" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Wikibooks-logo.svg/53px-Wikibooks-logo.svg.png 1.'
# b'5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Wikibooks-logo.svg/70px-Wikibooks-logo.svg.png 2x" data-file-width="300"'
# b' data-file-height="300" /></a></div>\n  <div><span><a href="https://en.wikibooks.org/wiki/" class="extiw" title="b:">Wikibooks</a'
# b'></span><br />Free textbooks and manuals</div>\n</li>\n<li>\n  <div><a href="https://www.wikidata.org/wiki/" title="Wikidata"><img '
# b'alt="Wikidata logo" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/ff/Wikidata-logo.svg/47px-Wikidata-logo.svg.png" decod'
# b'ing="async" width="47" height="26" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/ff/Wikidata-logo.svg/71px-Wikidata-l'
# b'ogo.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/ff/Wikidata-logo.svg/94px-Wikidata-logo.svg.png 2x" data-file'
# b'-width="1050" data-file-height="590" /></a></div>\n  <div><span><a href="https://www.wikidata.org/wiki/" class="extiw" title="d:"'
# b'>Wikidata</a></span><br />Free knowledge base</div>\n</li>\n<li>\n  <div><a href="https://en.wikinews.org/wiki/" title="Wikinews"><'
# b'img alt="Wikinews logo" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/24/Wikinews-logo.svg/51px-Wikinews-logo.svg.png" d'
# b'ecoding="async" width="51" height="28" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/24/Wikinews-logo.svg/77px-Wikine'
# b'ws-logo.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/2/24/Wikinews-logo.svg/102px-Wikinews-logo.svg.png 2x" data'
# b'-file-width="759" data-file-height="415" /></a></div>\n  <div><span><a href="https://en.wikinews.org/wiki/" class="extiw" title="'
# b'n:">Wikinews</a></span><br />Free-content news</div>\n</li>\n<li>\n  <div><a href="https://en.wikiquote.org/wiki/" title="Wikiquote'
# b'"><img alt="Wikiquote logo" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Wikiquote-logo.svg/35px-Wikiquote-logo.svg.'
# b'png" decoding="async" width="35" height="41" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Wikiquote-logo.svg/53px'
# b'-Wikiquote-logo.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Wikiquote-logo.svg/70px-Wikiquote-logo.svg.png'
# b' 2x" data-file-width="300" data-file-height="355" /></a></div>\n  <div><span><a href="https://en.wikiquote.org/wiki/" class="exti'
# b'w" title="q:">Wikiquote</a></span><br />Collection of quotations</div>\n</li>\n<li>\n  <div><a href="https://en.wikisource.org/wiki'
# b'/" title="Wikisource"><img alt="Wikisource logo" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/4c/Wikisource-logo.svg/35'
# b'px-Wikisource-logo.svg.png" decoding="async" width="35" height="37" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/4c/'
# b'Wikisource-logo.svg/53px-Wikisource-logo.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/4c/Wikisource-logo.svg/7'
# b'0px-Wikisource-logo.svg.png 2x" data-file-width="410" data-file-height="430" /></a></div>\n  <div><span><a href="https://en.wikis'
# b'ource.org/wiki/" class="extiw" title="s:">Wikisource</a></span><br />Free-content library</div>\n</li>\n<li>\n  <div><a href="https'
# b'://species.wikimedia.org/wiki/" title="Wikispecies"><img alt="Wikispecies logo" src="//upload.wikimedia.org/wikipedia/commons/th'
# b'umb/d/df/Wikispecies-logo.svg/35px-Wikispecies-logo.svg.png" decoding="async" width="35" height="41" srcset="//upload.wikimedia.'
# b'org/wikipedia/commons/thumb/d/df/Wikispecies-logo.svg/53px-Wikispecies-logo.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commo'
# b'ns/thumb/d/df/Wikispecies-logo.svg/70px-Wikispecies-logo.svg.png 2x" data-file-width="941" data-file-height="1103" /></a></div>\n'
# b'  <div><span><a href="https://species.wikimedia.org/wiki/" class="extiw" title="species:">Wikispecies</a></span><br />Directory '
# b'of species</div>\n</li>\n<li>\n  <div><a href="https://en.wikiversity.org/wiki/" title="Wikiversity"><img alt="Wikiversity logo" sr'
# b'c="//upload.wikimedia.org/wikipedia/commons/thumb/0/0b/Wikiversity_logo_2017.svg/41px-Wikiversity_logo_2017.svg.png" decoding="a'
# b'sync" width="41" height="34" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/0b/Wikiversity_logo_2017.svg/62px-Wikivers'
# b'ity_logo_2017.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/0/0b/Wikiversity_logo_2017.svg/82px-Wikiversity_logo_'
# b'2017.svg.png 2x" data-file-width="626" data-file-height="512" /></a></div>\n  <div><span><a href="https://en.wikiversity.org/wiki'
# b'/" class="extiw" title="v:">Wikiversity</a></span><br />Free learning tools</div>\n</li>\n<li>\n  <div><a href="https://en.wikivoya'
# b'ge.org/wiki/" title="Wikivoyage"><img alt="Wikivoyage logo" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/dd/Wikivoyage-'
# b'Logo-v3-icon.svg/35px-Wikivoyage-Logo-v3-icon.svg.png" decoding="async" width="35" height="35" srcset="//upload.wikimedia.org/wi'
# b'kipedia/commons/thumb/d/dd/Wikivoyage-Logo-v3-icon.svg/53px-Wikivoyage-Logo-v3-icon.svg.png 1.5x, //upload.wikimedia.org/wikiped'
# b'ia/commons/thumb/d/dd/Wikivoyage-Logo-v3-icon.svg/70px-Wikivoyage-Logo-v3-icon.svg.png 2x" data-file-width="193" data-file-heigh'
# b't="193" /></a></div>\n  <div><span><a href="https://en.wikivoyage.org/wiki/" class="extiw" title="voy:">Wikivoyage</a></span><br '
# b'/>Free travel guide</div>\n</li>\n<li>\n  <div><a href="https://en.wiktionary.org/wiki/" title="Wiktionary"><img alt="Wiktionary lo'
# b'go" src="//upload.wikimedia.org/wikipedia/en/thumb/0/06/Wiktionary-logo-v2.svg/35px-Wiktionary-logo-v2.svg.png" decoding="async"'
# b' width="35" height="35" srcset="//upload.wikimedia.org/wikipedia/en/thumb/0/06/Wiktionary-logo-v2.svg/53px-Wiktionary-logo-v2.sv'
# b'g.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/0/06/Wiktionary-logo-v2.svg/70px-Wiktionary-logo-v2.svg.png 2x" data-file-'
# b'width="391" data-file-height="391" /></a></div>\n  <div><span><a href="https://en.wiktionary.org/wiki/" class="extiw" title="wikt'
# b':">Wiktionary</a></span><br />Dictionary and thesaurus</div>\n</li>\n</ul>\n</div></div>\n<h2 id="mp-lang" class="mp-h2"><span class'
# b'="mw-headline" id="Wikipedia_languages">Wikipedia languages</span></h2>\n<div><style data-mw-deduplicate="TemplateStyles:r9972729'
# b'51">.mw-parser-output .wikipedia-languages-complete{font-weight:bold}.mw-parser-output .wikipedia-languages ul{margin-left:0}.mw'
# b'-parser-output .wikipedia-languages ul a{white-space:nowrap}.mw-parser-output .wikipedia-languages>ul{list-style:none;text-align'
# b':center;clear:both}.mw-parser-output .wikipedia-languages-count-container{width:90%;display:flex;justify-content:center;padding-'
# b'top:1em;margin:0 auto}.mw-parser-output .wikipedia-languages-prettybars{width:100%;height:1px;margin:0.5em 0;background-color:#c'
# b'8ccd1;flex-shrink:1;align-self:center}.mw-parser-output .wikipedia-languages-count{padding:0 1em;white-space:nowrap}</style>\n<di'
# b'v class="wikipedia-languages nourlexpansion">\n<p>This Wikipedia is written in <a href="/wiki/English_language" title="English la'
# b'nguage">English</a>. Many <a href="https://meta.wikimedia.org/wiki/List_of_Wikipedias" class="extiw" title="meta:List of Wikiped'
# b'ias">other Wikipedias are available</a>; some of the largest are listed below.\n</p>\n<ul class="plainlinks">\n<li>\n  <div class="w'
# b'ikipedia-languages-count-container">\n    <div class="wikipedia-languages-prettybars"></div>\n    <div role="heading" class="wikip'
# b'edia-languages-count">1,000,000+ articles</div>\n    <div class="wikipedia-languages-prettybars"></div>\n  </div>\n  <ul class="wik'
# b'ipedia-languages-langs hlist hlist-separated inline">\n    <li><a class="external text" href="https://ar.wikipedia.org/wiki/"><sp'
# b'an class="autonym" title="Arabic (ar:)" lang="ar">\xd8\xa7\xd9\x84\xd8\xb9\xd8\xb1\xd8\xa8\xd9\x8a\xd8\xa9</span></a></li>\n    <li><a class="external text" href="https://'
# b'de.wikipedia.org/wiki/"><span class="autonym" title="German (de:)" lang="de">Deutsch</span></a></li>\n    <li><a class="external '
# b'text" href="https://es.wikipedia.org/wiki/"><span class="autonym" title="Spanish (es:)" lang="es">Espa\xc3\xb1ol</span></a></li>\n    <'
# b'li><a class="external text" href="https://fr.wikipedia.org/wiki/"><span class="autonym" title="French (fr:)" lang="fr">Fran\xc3\xa7ais'
# b'</span></a></li>\n    <li><a class="external text" href="https://it.wikipedia.org/wiki/"><span class="autonym" title="Italian (it'
# b':)" lang="it">Italiano</span></a></li>\n    <li><a class="external text" href="https://nl.wikipedia.org/wiki/"><span class="auton'
# b'ym" title="Dutch (nl:)" lang="nl">Nederlands</span></a></li>\n    <li><a class="external text" href="https://ja.wikipedia.org/wik'
# b'i/"><span class="autonym" title="Japanese (ja:)" lang="ja">\xe6\x97\xa5\xe6\x9c\xac\xe8\xaa\x9e</span></a></li>\n    <li><a class="external text" href="http'
# b's://pl.wikipedia.org/wiki/"><span class="autonym" title="Polish (pl:)" lang="pl">Polski</span></a></li>\n    <li><a class="extern'
# b'al text" href="https://pt.wikipedia.org/wiki/"><span class="autonym" title="Portuguese (pt:)" lang="pt">Portugu\xc3\xaas</span></a></l'
# b'i>\n    <li><a class="external text" href="https://ru.wikipedia.org/wiki/"><span class="autonym" title="Russian (ru:)" lang="ru">'
# ...
# b'em"><a href="https://ca.wikipedia.org/wiki/" title="Catalan" lang="ca" hreflang="ca" class="interlanguage-link-target"><span>Cat'
# b'al\xc3\xa0</span></a></li><li class="interlanguage-link interwiki-cs mw-list-item"><a href="https://cs.wikipedia.org/wiki/" title="Cze'
# b'ch" lang="cs" hreflang="cs" class="interlanguage-link-target"><span>\xc4\x8ce\xc5\xa1tina</span></a></li><li class="interlanguage-link inter'
# b'wiki-da mw-list-item"><a href="https://da.wikipedia.org/wiki/" title="Danish" lang="da" hreflang="da" class="interlanguage-link-'
# b'target"><span>Dansk</span></a></li><li class="interlanguage-link interwiki-de mw-list-item"><a href="https://de.wikipedia.org/wi'
# b'ki/" title="German" lang="de" hreflang="de" class="interlanguage-link-target"><span>Deutsch</span></a></li><li class="interlangu'
# b'age-link interwiki-et mw-list-item"><a href="https://et.wikipedia.org/wiki/" title="Estonian" lang="et" hreflang="et" class="int'
# b'erlanguage-link-target"><span>Eesti</span></a></li><li class="interlanguage-link interwiki-el mw-list-item"><a href="https://el.'
# b'wikipedia.org/wiki/" title="Greek" lang="el" hreflang="el" class="interlanguage-link-target"><span>\xce\x95\xce\xbb\xce\xbb\xce\xb7\xce\xbd\xce\xb9\xce\xba\xce\xac</span></a></'
# b'li><li class="interlanguage-link interwiki-es mw-list-item"><a href="https://es.wikipedia.org/wiki/" title="Spanish" lang="es" h'
# b'reflang="es" class="interlanguage-link-target"><span>Espa\xc3\xb1ol</span></a></li><li class="interlanguage-link interwiki-eo mw-list-'
# b'item"><a href="https://eo.wikipedia.org/wiki/" title="Esperanto" lang="eo" hreflang="eo" class="interlanguage-link-target"><span'
# b'>Esperanto</span></a></li><li class="interlanguage-link interwiki-eu mw-list-item"><a href="https://eu.wikipedia.org/wiki/" titl'
# b'e="Basque" lang="eu" hreflang="eu" class="interlanguage-link-target"><span>Euskara</span></a></li><li class="interlanguage-link '
# b'interwiki-fa mw-list-item"><a href="https://fa.wikipedia.org/wiki/" title="Persian" lang="fa" hreflang="fa" class="interlanguage'
# b'-link-target"><span>\xd9\x81\xd8\xa7\xd8\xb1\xd8\xb3\xdb\x8c</span></a></li><li class="interlanguage-link interwiki-fr mw-list-item"><a href="https://fr.wikip'
# b'edia.org/wiki/" title="French" lang="fr" hreflang="fr" class="interlanguage-link-target"><span>Fran\xc3\xa7ais</span></a></li><li clas'
# b's="interlanguage-link interwiki-gl mw-list-item"><a href="https://gl.wikipedia.org/wiki/" title="Galician" lang="gl" hreflang="g'
# b'l" class="interlanguage-link-target"><span>Galego</span></a></li><li class="interlanguage-link interwiki-ko mw-list-item"><a hre'
# b'f="https://ko.wikipedia.org/wiki/" title="Korean" lang="ko" hreflang="ko" class="interlanguage-link-target"><span>\xed\x95\x9c\xea\xb5\xad\xec\x96\xb4</spa'
# b'n></a></li><li class="interlanguage-link interwiki-hr mw-list-item"><a href="https://hr.wikipedia.org/wiki/" title="Croatian" la'
# b'ng="hr" hreflang="hr" class="interlanguage-link-target"><span>Hrvatski</span></a></li><li class="interlanguage-link interwiki-id'
# b' mw-list-item"><a href="https://id.wikipedia.org/wiki/" title="Indonesian" lang="id" hreflang="id" class="interlanguage-link-tar'
# b'get"><span>Bahasa Indonesia</span></a></li><li class="interlanguage-link interwiki-it mw-list-item"><a href="https://it.wikipedi'
# b'a.org/wiki/" title="Italian" lang="it" hreflang="it" class="interlanguage-link-target"><span>Italiano</span></a></li><li class="'
# b'interlanguage-link interwiki-he mw-list-item"><a href="https://he.wikipedia.org/wiki/" title="Hebrew" lang="he" hreflang="he" cl'
# b'ass="interlanguage-link-target"><span>\xd7\xa2\xd7\x91\xd7\xa8\xd7\x99\xd7\xaa</span></a></li><li class="interlanguage-link interwiki-ka mw-list-item"><a href'
# b'="https://ka.wikipedia.org/wiki/" title="Georgian" lang="ka" hreflang="ka" class="interlanguage-link-target"><span>\xe1\x83\xa5\xe1\x83\x90\xe1\x83\xa0\xe1\x83\x97\xe1'
# b'\x83\xa3\xe1\x83\x9a\xe1\x83\x98</span></a></li><li class="interlanguage-link interwiki-lv mw-list-item"><a href="https://lv.wikipedia.org/wiki/" title='
# b'"Latvian" lang="lv" hreflang="lv" class="interlanguage-link-target"><span>Latvie\xc5\xa1u</span></a></li><li class="interlanguage-link'
# b' interwiki-lt mw-list-item"><a href="https://lt.wikipedia.org/wiki/" title="Lithuanian" lang="lt" hreflang="lt" class="interlang'
# b'uage-link-target"><span>Lietuvi\xc5\xb3</span></a></li><li class="interlanguage-link interwiki-hu mw-list-item"><a href="https://hu.wi'
# b'kipedia.org/wiki/" title="Hungarian" lang="hu" hreflang="hu" class="interlanguage-link-target"><span>Magyar</span></a></li><li c'
# b'lass="interlanguage-link interwiki-mk mw-list-item"><a href="https://mk.wikipedia.org/wiki/" title="Macedonian" lang="mk" hrefla'
# b'ng="mk" class="interlanguage-link-target"><span>\xd0\x9c\xd0\xb0\xd0\xba\xd0\xb5\xd0\xb4\xd0\xbe\xd0\xbd\xd1\x81\xd0\xba\xd0\xb8</span></a></li><li class="interlanguage-link interwiki-ms m'
# b'w-list-item"><a href="https://ms.wikipedia.org/wiki/" title="Malay" lang="ms" hreflang="ms" class="interlanguage-link-target"><s'
# b'pan>Bahasa Melayu</span></a></li><li class="interlanguage-link interwiki-nl mw-list-item"><a href="https://nl.wikipedia.org/wiki'
# b'/" title="Dutch" lang="nl" hreflang="nl" class="interlanguage-link-target"><span>Nederlands</span></a></li><li class="interlangu'
# b'age-link interwiki-ja mw-list-item"><a href="https://ja.wikipedia.org/wiki/" title="Japanese" lang="ja" hreflang="ja" class="int'
# b'erlanguage-link-target"><span>\xe6\x97\xa5\xe6\x9c\xac\xe8\xaa\x9e</span></a></li><li class="interlanguage-link interwiki-no mw-list-item"><a href="https:/'
# b'/no.wikipedia.org/wiki/" title="Norwegian Bokm\xc3\xa5l" lang="nb" hreflang="nb" class="interlanguage-link-target"><span>Norsk bokm\xc3\xa5l'
# b'</span></a></li><li class="interlanguage-link interwiki-nn mw-list-item"><a href="https://nn.wikipedia.org/wiki/" title="Norwegi'
# b'an Nynorsk" lang="nn" hreflang="nn" class="interlanguage-link-target"><span>Norsk nynorsk</span></a></li><li class="interlanguag'
# b'e-link interwiki-pl mw-list-item"><a href="https://pl.wikipedia.org/wiki/" title="Polish" lang="pl" hreflang="pl" class="interla'
# b'nguage-link-target"><span>Polski</span></a></li><li class="interlanguage-link interwiki-pt mw-list-item"><a href="https://pt.wik'
# b'ipedia.org/wiki/" title="Portuguese" lang="pt" hreflang="pt" class="interlanguage-link-target"><span>Portugu\xc3\xaas</span></a></li><'
# b'li class="interlanguage-link interwiki-ro mw-list-item"><a href="https://ro.wikipedia.org/wiki/" title="Romanian" lang="ro" href'
# b'lang="ro" class="interlanguage-link-target"><span>Rom\xc3\xa2n\xc4\x83</span></a></li><li class="interlanguage-link interwiki-ru mw-list-ite'
# b'm"><a href="https://ru.wikipedia.org/wiki/" title="Russian" lang="ru" hreflang="ru" class="interlanguage-link-target"><span>\xd0\xa0\xd1\x83'
# b'\xd1\x81\xd1\x81\xd0\xba\xd0\xb8\xd0\xb9</span></a></li><li class="interlanguage-link interwiki-simple mw-list-item"><a href="https://simple.wikipedia.org/wik'
# b'i/" title="Simple English" lang="en-simple" hreflang="en-simple" class="interlanguage-link-target"><span>Simple English</span></'
# b'a></li><li class="interlanguage-link interwiki-sk mw-list-item"><a href="https://sk.wikipedia.org/wiki/" title="Slovak" lang="sk'
# b'" hreflang="sk" class="interlanguage-link-target"><span>Sloven\xc4\x8dina</span></a></li><li class="interlanguage-link interwiki-sl mw'
# b'-list-item"><a href="https://sl.wikipedia.org/wiki/" title="Slovenian" lang="sl" hreflang="sl" class="interlanguage-link-target"'
# b'><span>Sloven\xc5\xa1\xc4\x8dina</span></a></li><li class="interlanguage-link interwiki-sr mw-list-item"><a href="https://sr.wikipedia.org/w'
# b'iki/" title="Serbian" lang="sr" hreflang="sr" class="interlanguage-link-target"><span>\xd0\xa1\xd1\x80\xd0\xbf\xd1\x81\xd0\xba\xd0\xb8 / srpski</span></a></li><li c'
# b'lass="interlanguage-link interwiki-sh mw-list-item"><a href="https://sh.wikipedia.org/wiki/" title="Serbo-Croatian" lang="sh" hr'
# b'eflang="sh" class="interlanguage-link-target"><span>Srpskohrvatski / \xd1\x81\xd1\x80\xd0\xbf\xd1\x81\xd0\xba\xd0\xbe\xd1\x85\xd1\x80\xd0\xb2\xd0\xb0\xd1\x82\xd1\x81\xd0\xba\xd0\xb8</span></a></li><li class="inte'
# b'rlanguage-link interwiki-fi mw-list-item"><a href="https://fi.wikipedia.org/wiki/" title="Finnish" lang="fi" hreflang="fi" class'
# b'="interlanguage-link-target"><span>Suomi</span></a></li><li class="interlanguage-link interwiki-sv mw-list-item"><a href="https:'
# b'//sv.wikipedia.org/wiki/" title="Swedish" lang="sv" hreflang="sv" class="interlanguage-link-target"><span>Svenska</span></a></li'
# b'><li class="interlanguage-link interwiki-th mw-list-item"><a href="https://th.wikipedia.org/wiki/" title="Thai" lang="th" hrefla'
# b'ng="th" class="interlanguage-link-target"><span>\xe0\xb9\x84\xe0\xb8\x97\xe0\xb8\xa2</span></a></li><li class="interlanguage-link interwiki-tr mw-list-item'
# b'"><a href="https://tr.wikipedia.org/wiki/" title="Turkish" lang="tr" hreflang="tr" class="interlanguage-link-target"><span>T\xc3\xbcrk'
# b'\xc3\xa7e</span></a></li><li class="interlanguage-link interwiki-uk mw-list-item"><a href="https://uk.wikipedia.org/wiki/" title="Ukra'
# b'inian" lang="uk" hreflang="uk" class="interlanguage-link-target"><span>\xd0\xa3\xd0\xba\xd1\x80\xd0\xb0\xd1\x97\xd0\xbd\xd1\x81\xd1\x8c\xd0\xba\xd0\xb0</span></a></li><li class="interlangu'
# b'age-link interwiki-vi mw-list-item"><a href="https://vi.wikipedia.org/wiki/" title="Vietnamese" lang="vi" hreflang="vi" class="i'
# b'nterlanguage-link-target"><span>Ti\xe1\xba\xbfng Vi\xe1\xbb\x87t</span></a></li><li class="interlanguage-link interwiki-zh mw-list-item"><a href="'
# b'https://zh.wikipedia.org/wiki/" title="Chinese" lang="zh" hreflang="zh" class="interlanguage-link-target"><span>\xe4\xb8\xad\xe6\x96\x87</span></a'
# b'></li></ul>\n\t\t\n\t</div>\n</nav>\n\n</div>\n\n</div>\n\n<footer id="footer" class="mw-footer" role="contentinfo" >\n\t<ul id="footer-info">'
# b'\n\t<li id="footer-info-lastmod"> This page was last edited on 28 April 2022, at 21:25<span class="anonymous-show">&#160;(UTC)</sp'
# b'an>.</li>\n\t<li id="footer-info-copyright">Text is available under the <a rel="license" href="//en.wikipedia.org/wiki/Wikipedia:T'
# b'ext_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License">Creative Commons Attribution-ShareAlike License 3.0</a><a r'
# b'el="license" href="//creativecommons.org/licenses/by-sa/3.0/" style="display:none;"></a>;\nadditional terms may apply.  By using '
# b'this site, you agree to the <a href="//foundation.wikimedia.org/wiki/Terms_of_Use">Terms of Use</a> and <a href="//foundation.wi'
# b'kimedia.org/wiki/Privacy_policy">Privacy Policy</a>. Wikipedia\xc2\xae is a registered trademark of the <a href="//www.wikimediafounda'
# b'tion.org/">Wikimedia Foundation, Inc.</a>, a non-profit organization.</li>\n</ul>\n\n\t<ul id="footer-places">\n\t<li id="footer-place'
# b's-privacy"><a href="https://foundation.wikimedia.org/wiki/Privacy_policy" class="extiw" title="wmf:Privacy policy">Privacy polic'
# b'y</a></li>\n\t<li id="footer-places-about"><a href="/wiki/Wikipedia:About" title="Wikipedia:About">About Wikipedia</a></li>\n\t<li i'
# b'd="footer-places-disclaimer"><a href="/wiki/Wikipedia:General_disclaimer" title="Wikipedia:General disclaimer">Disclaimers</a></'
# b'li>\n\t<li id="footer-places-contact"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us">Contact Wikipedia</a></li>\n\t<li id="f'
# b'ooter-places-mobileview"><a href="//en.m.wikipedia.org/w/index.php?title=Main_Page&amp;mobileaction=toggle_view_mobile" class="n'
# b'oprint stopMobileRedirectToggle">Mobile view</a></li>\n\t<li id="footer-places-developers"><a href="https://www.mediawiki.org/wiki'
# b'/Special:MyLanguage/How_to_contribute">Developers</a></li>\n\t<li id="footer-places-statslink"><a href="https://stats.wikimedia.or'
# b'g/#/en.wikipedia.org">Statistics</a></li>\n\t<li id="footer-places-cookiestatement"><a href="https://foundation.wikimedia.org/wiki'
# b'/Cookie_statement">Cookie statement</a></li>\n</ul>\n\n\t<ul id="footer-icons" class="noprint">\n\t<li id="footer-copyrightico"><a hre'
# b'f="https://wikimediafoundation.org/"><img src="/static/images/footer/wikimedia-button.png" srcset="/static/images/footer/wikimed'
# b'ia-button-1.5x.png 1.5x, /static/images/footer/wikimedia-button-2x.png 2x" width="88" height="31" alt="Wikimedia Foundation" loa'
# b'ding="lazy" /></a></li>\n\t<li id="footer-poweredbyico"><a href="https://www.mediawiki.org/"><img src="/static/images/footer/power'
# b'edby_mediawiki_88x31.png" alt="Powered by MediaWiki" srcset="/static/images/footer/poweredby_mediawiki_132x47.png 1.5x, /static/'
# b'images/footer/poweredby_mediawiki_176x62.png 2x" width="88" height="31" loading="lazy"/></a></li>\n</ul>\n\n</footer>\n\n<script>(RLQ'
# b'=window.RLQ||[]).push(function(){mw.config.set({"wgPageParseReport":{"limitreport":{"cputime":"0.438","walltime":"0.533","ppvisi'
# b'tednodes":{"value":4370,"limit":1000000},"postexpandincludesize":{"value":131312,"limit":2097152},"templateargumentsize":{"value'
# b'":12327,"limit":2097152},"expansiondepth":{"value":20,"limit":100},"expensivefunctioncount":{"value":15,"limit":500},"unstrip-de'
# b'pth":{"value":0,"limit":20},"unstrip-size":{"value":4865,"limit":5000000},"entityaccesscount":{"value":0,"limit":400},"timingpro'
# b'file":["100.00%  376.253      1 -total"," 46.29%  174.172      1 Wikipedia:Main_Page/Tomorrow"," 25.78%   97.000      9 Template'
# b':Main_page_image"," 17.31%   65.129      9 Template:Str_number/trim"," 16.92%   63.655      2 Template:Wikipedia_languages"," 14'
# b'.18%   53.338      1 Wikipedia:Today\'s_featured_article/June_12,_2022"," 13.27%   49.931      2 Template:In_the_news"," 13.16%  '
# b' 49.507      2 Template:Main_page_image/TFA"," 11.65%   43.844    100 Template:Wikipedia_languages/core"," 10.87%   40.904      '
# b'1 Wikipedia:Selected_anniversaries/June_13"]},"scribunto":{"limitreport-timeusage":{"value":"0.082","limit":"10.000"},"limitrepo'
# b'rt-memusage":{"value":2742239,"limit":52428800}},"cachereport":{"origin":"mw1387","timestamp":"20220612150810","ttl":3600,"trans'
# b'ientcontent":true}}});});</script>\n<script type="application/ld+json">{"@context":"https:\\/\\/schema.org","@type":"Article","name'
# b'":"Main Page","url":"https:\\/\\/en.wikipedia.org\\/wiki\\/Main_Page","sameAs":"http:\\/\\/www.wikidata.org\\/entity\\/Q5296","mainEntit'
# b'y":"http:\\/\\/www.wikidata.org\\/entity\\/Q5296","author":{"@type":"Organization","name":"Contributors to Wikimedia projects"},"pub'
# b'lisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\\/\\/www.wikimedia'
# b'.org\\/static\\/images\\/wmf-hor-googpub.png"}},"datePublished":"2002-01-26T15:28:12Z","dateModified":"2022-04-28T21:25:27Z","image'
# b'":"https:\\/\\/upload.wikimedia.org\\/wikipedia\\/commons\\/3\\/3d\\/Tower_House%2C_Kensington%2C_January_2015_03.jpg","headline":"Wiki'
# b'media project page"}</script><script type="application/ld+json">{"@context":"https:\\/\\/schema.org","@type":"Article","name":"Mai'
# b'n Page","url":"https:\\/\\/en.wikipedia.org\\/wiki\\/Main_Page","sameAs":"http:\\/\\/www.wikidata.org\\/entity\\/Q5296","mainEntity":"ht'
# b'tp:\\/\\/www.wikidata.org\\/entity\\/Q5296","author":{"@type":"Organization","name":"Contributors to Wikimedia projects"},"publisher'
# b'":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\\/\\/www.wikimedia.org\\/'
# b'static\\/images\\/wmf-hor-googpub.png"}},"datePublished":"2002-01-26T15:28:12Z","dateModified":"2022-04-28T21:25:27Z","image":"htt'
# b'ps:\\/\\/upload.wikimedia.org\\/wikipedia\\/commons\\/3\\/3d\\/Tower_House%2C_Kensington%2C_January_2015_03.jpg","headline":"Wikimedia '
# b'project page"}</script>\n<script>(RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgBackendResponseTime":129,"wgHostname":"mw'
# b'1414"});});</script>\n</body>\n</html>'

# %% [markdown]
# ### Exercise 2: Write a small function to check the status of web request
#
# This kind of small helper/utility functions are incredibly useful for complex projects.
#
# Start building **a habit of writing small functions to accomplish small modular tasks**, instead of writing long scripts, which are hard to debug and track.

# %%
def status_check(r):
    if r.status_code==200:
        print("Success!")
        return 1
    else:
        print("Failed!")
        return -1

# %%
status_check(response)
# Out:
# Success!
# 1

# %% [markdown]
# ### Exercise 3: Write small function to check the encoding of the web page

# %%
def encoding_check(r):
    return (r.encoding)

# %%
encoding_check(response)
# Out:
# 'UTF-8'

# %% [markdown]
# ### Exercise 4: Write a small function to decode the concents of the `response`

# %%
def decode_content(r,encoding):
    return (r.content.decode(encoding))

# %%
contents = decode_content(response,encoding_check(response))

# %% [markdown]
# #### What is the type of the contents?

# %%
type(contents)
# Out:
# str

# %% [markdown]
# #### Fantastic! Finally we got a string object. Did you see how easy it was to read text from a popular webpage like Wikipedia?

# %% [markdown]
# ### Exercise 5: Check the length of the text you got back and print some selected portions

# %%
len(contents)
# Out:
# 84449

# %%
print(contents[:1000])
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>Wikipedia, the free encyclopedia</title>
# <script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"240ed5bf-6f05-4c48-9b4b-4ca09608373a","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Main_Page","wgTitle":"Main Page","wgCurRevisionId":1085170884,"wgRevisionId":1085170884,"wgArticleId":15580374,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":[],"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"Main_Page","wgRelevantArticleId":15580374,"wgIsProbablyEditable":fals

# %%
print(contents[15000:16000])
# Out:
# /" class="extiw" title="mail:daily-article-l">By email</a></b></li>
# <li><b><a href="/wiki/Wikipedia:Featured_articles" title="Wikipedia:Featured articles">More featured articles</a></b></li></ul>
# </div></div>
# <h2 id="mp-dyk-h2" class="mp-h2"><span class="mw-headline" id="Did_you_know_...">Did you know&#160;...</span></h2>
# <div id="mp-dyk">
# <div class="dyk-img" style="float: right; margin-left: 0.5em;">
# <div class="thumbinner mp-thumb" style="background: transparent; border: none; padding: 0; max-width: 156px;">
# <a href="/wiki/File:Levitan_Evening_bells_1892.jpg" class="image" title="Evening Bells by Isaac Levitan"><img alt="Evening Bells by Isaac Levitan" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/15/Levitan_Evening_bells_1892.jpg/156px-Levitan_Evening_bells_1892.jpg" decoding="async" width="156" height="125" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/15/Levitan_Evening_bells_1892.jpg/234px-Levitan_Evening_bells_1892.jpg 1.5x, //upload.wikimedia.org/wikipedia/c

# %% [markdown]
# ### Exercise 6: Use `BeautifulSoup` package to parse the raw HTML text more meaningfully and search for a particular text

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(contents, 'html.parser')

# %% [markdown]
# #### What is this new `soup` object?

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %% [markdown]
# ### Exercise 7: Can we somehow read intelligible text from this `soup` object?

# %%
txt_dump=soup.text

# %%
type(txt_dump)
# Out:
# str

# %%
len(txt_dump)
# Out:
# 8548

# %%
print(txt_dump[0:])
# Out:
# Wikipedia, the free encyclopedia
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Main Page
#
# From Wikipedia, the free encyclopedia
#
#
#
# Jump to navigation
# Jump to search
#
#
#
# Welcome to Wikipedia,
# the free encyclopedia that anyone can edit.
# 6,512,161 articles in English
#
#
#
#
#
# From today's featured article
#
#
#
#
# The Tower House, in the district of Holland Park in Kensington and Chelsea, London, is a late Victorian townhouse built between 1875 and 1881 by the architect and designer William Burges as his personal residence. Designed in the French Gothic Revival style, it echoes elements of Burges's earlier work. The house was built of red brick by the Ashby Brothers, with a distinctive cylindrical tower and conical roof. The interior was decorated by members of Burges's long-standing team of craftsmen including Thomas Nicholls and Henry Stacy Marks. The house retains most of its internal structural decoration, but much of the furniture, fittings and contents that Burges designed have been dispersed. Many items, including the Great Bookcase, the Zodiac settle, the Golden Bed and the Red Bed, are now in institutions such as The Higgins Bedford and the Victoria and Albert Museum. The house was designated a Grade I listed building in 1949. (Full article...)
#
#
# Recently featured:
# Hurricane Leslie (2018)
# Mosasaurus
# On the Job (2013 film)
#
#
# Archive
# By email
# More featured articles
#
# Did you know ...
#
#
#
# Evening Bells by Isaac Levitan
#
# ... that Isaac Levitan was inspired to paint Evening Bells (pictured) when he came across a small monastery in a remote village?
# ... that Sam Smith left the University of Louisville after being found to be academically ineligible for  its basketball team, claiming the school was "too big for him"?
# ... that the adoption of the Declaration of Independence of Azerbaijan made the Azerbaijan Democratic Republic the first successful republic in the Muslim world?
# ... that Arnold Blackner was said to be the first person to sing over 3,000 miles on the telephone?
# ... that the literary movement of créolie tries to integrate the identity of Réunion with France?
# ... that  the Four-Track News is not news about the car music cassettes of the 1950s, but an illustrated magazine of the early 1900s on travel and education put out by the New York Central Railroad?
# ... that records of Acoutsina's captivity allow historians to analyse the eighteenth century French-Eskimo relationship?
# ... that a regional radio group with 75 stations started with a "Big Wrig"?
#
# Archive
# Start a new article
# Nominate an article
#
#
#
#
#
#
# In the news
#
#
# Jeanine Áñez
#
# Former Bolivian president Jeanine Áñez (pictured) is sentenced to ten years in prison on charges related to her succession to office during the 2019 political crisis.
# In Nigeria, at least 40 people are killed in an attack at a Catholic church in Owo, Ondo State.
# A fire and explosions at a storage depot in Sitakunda, Bangladesh, kill at least 41 people and injure more than 450 others.
# The Common­wealth of Nations celebrates the Platinum Jubilee of Elizabeth II.
#
# Ongoing:
# COVID-19 pandemic
# Russian invasion of Ukraine
# Recent deaths:
# Christof May
# Julee Cruise
# Erasmus Schöfer
# Paula Rego
# Christopher Pratt
# Dorothy E. Smith
#
# Nominate an article
#
# On this day
#
# June 12: Dia dos Namorados in Brazil; Independence Day in the Philippines (1898); Loving Day in the United States (1967)
#
#
#
# Anne Frank
#
# 1798 – Following the successful French invasion of Malta, the Knights Hospitaller surrendered Malta to Napoleon, initiating two years of occupation.
# 1899 – The New Richmond tornado killed 117 people and injured 125 others in the Upper Midwest region of the United States.
# 1942 – On her thirteenth birthday, Anne Frank (pictured) began keeping a diary during the Nazi occupation of the Netherlands in World War II.
# 1991 – More than 150 Sri Lankan Tamil civilians were massacred by members of the military in the village of Kokkadichcholai.
# Thomas Farnaby  (d. 1647)Egwale Seyon  (d. 1818)Javed Miandad  (b. 1957)
#
# More anniversaries:
# June 11
# June 12
# June 13
#
#
# Archive
# By email
# List of days of the year
#
#
#
#
# Today's featured picture
#
#
#
#
#
#
# The Notre-Dame fire broke out in the cathedral of Notre-Dame de Paris on 15 April 2019, causing severe damage to the building's spire, roof, and upper walls. The fire resulted in the contamination of the site and nearby areas of the city with toxic dust and lead. Investigators believed that the fire was caused by a cigarette or an electrical short circuit; the prosecutor of Paris found no evidence showing the fire was started deliberately. The cathedral's wooden spire, or flèche, was built by Eugène Viollet-le-Duc in the Gothic Revival style and installed in 1859, weighing around 250 tons. This photograph, taken during the 2019 fire, depicts the spire of Notre-Dame aflame; it collapsed shortly afterwards.
#
# Photograph credit: Guillaume Levrier
#
# Recently featured:
# Julia Margaret Cameron
# Sinopterus dongi
# The Anatomy Lesson of Dr. Nicolaes Tulp
#
#
# Archive
# More featured pictures
#
#
#
#
#
# Other areas of Wikipedia
#
# Community portal – The central hub for editors, with resources, links, tasks, and announcements.
# Village pump – Forum for discussions about Wikipedia itself, including policies and technical issues.
# Site news – Sources of news about Wikipedia and the broader Wikimedia movement.
# Teahouse – Ask basic questions about using or editing Wikipedia.
# Help desk – Ask questions about using or editing Wikipedia.
# Reference desk – Ask research questions about encyclopedic topics.
# Content portals – A unique way to navigate the encyclopedia.
#
# Wikipedia's sister projects
#
# Wikipedia is written by volunteer editors and hosted by the Wikimedia Foundation, a non-profit organization that also hosts a range of other volunteer projects:
#
#
#
#
#
# CommonsFree media repository
#
#
#
# MediaWikiWiki software development
#
#
#
# Meta-WikiWikimedia project coordination
#
#
#
# WikibooksFree textbooks and manuals
#
#
#
# WikidataFree knowledge base
#
#
#
# WikinewsFree-content news
#
#
#
# WikiquoteCollection of quotations
#
#
#
# WikisourceFree-content library
#
#
#
# WikispeciesDirectory of species
#
#
#
# WikiversityFree learning tools
#
#
#
# WikivoyageFree travel guide
#
#
#
# WiktionaryDictionary and thesaurus
#
#
#
# Wikipedia languages
#
#
# This Wikipedia is written in English. Many other Wikipedias are available; some of the largest are listed below.
#
#
#
#
#
# 1,000,000+ articles
#
#
#
# العربية
# Deutsch
# Español
# Français
# Italiano
# Nederlands
# 日本語
# Polski
# Português
# Русский
# Svenska
# Українська
# Tiếng Việt
# 中文
#
#
#
#
#
# 250,000+ articles
#
#
#
# Bahasa Indonesia
# Bahasa Melayu
# Bân-lâm-gú
# Български
# Català
# Čeština
# Dansk
# Esperanto
# Euskara
# فارسی‎
# עברית
# 한국어
# Magyar
# Norsk Bokmål
# Română
# Srpski
# Srpskohrvatski
# Suomi
# Türkçe
#
#
#
#
#
# 50,000+ articles
#
#
#
# Asturianu
# বাংলা
# Bosanski
# Eesti
# Ελληνικά
# Simple English
# Galego
# Hrvatski
# Latviešu
# Lietuvių
# മലയാളം
# Македонски
# Norsk nynorsk
# Shqip
# Slovenčina
# Slovenščina
# ไทย
#
#
#
#
#
#
#
#
#
# Retrieved from "https://en.wikipedia.org/w/index.php?title=Main_Page&oldid=1085170884"
#
#
#
#
# Navigation menu
#
#
#
# Personal tools
#
#
# Not logged inTalkContributionsCreate accountLog in
#
#
#
#
#
# Namespaces
#
#
# Main PageTalk
#
#
#
#
#
# English
#
#
#
#
#
#
#
#
#
# Views
#
#
# ReadView sourceView history
#
#
#
#
#
# More
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Navigation
#
#
# Main pageContentsCurrent eventsRandom articleAbout WikipediaContact usDonate
#
#
#
#
# Contribute
#
#
# HelpLearn to editCommunity portalRecent changesUpload file
#
#
#
#
# Tools
#
#
# What links hereRelated changesUpload fileSpecial pagesPermanent linkPage informationCite this pageWikidata item
#
#
#
#
# Print/export
#
#
# Download as PDFPrintable version
#
#
#
#
# In other projects
#
#
# Wikimedia CommonsMediaWikiMeta-WikiMultilingual WikisourceWikispeciesWikibooksWikidataWikimaniaWikinewsWikiquoteWikisourceWikiversityWikivoyageWiktionary
#
#
#
#
# Languages
#
#
# العربيةবাংলাБългарскиBosanskiCatalàČeštinaDanskDeutschEestiΕλληνικάEspañolEsperantoEuskaraفارسیFrançaisGalego한국어HrvatskiBahasa IndonesiaItalianoעבריתქართულიLatviešuLietuviųMagyarМакедонскиBahasa MelayuNederlands日本語Norsk bokmålNorsk nynorskPolskiPortuguêsRomânăРусскийSimple EnglishSlovenčinaSlovenščinaСрпски / srpskiSrpskohrvatski / српскохрватскиSuomiSvenskaไทยTürkçeУкраїнськаTiếng Việt中文
#
#
#
#
#
#
#  This page was last edited on 28 April 2022, at 21:25 (UTC).
# Text is available under the Creative Commons Attribution-ShareAlike License 3.0;
# additional terms may apply.  By using this site, you agree to the Terms of Use and Privacy Policy. Wikipedia® is a registered trademark of the Wikimedia Foundation, Inc., a non-profit organization.
#
#
# Privacy policy
# About Wikipedia
# Disclaimers
# Contact Wikipedia
# Mobile view
# Developers
# Statistics
# Cookie statement

# %% [markdown]
# ### Exercise 8: Extract the text from the section *'From today's featured article'*

# %%
# First extract the starting and end indecies of the text we are interested in
idx1=txt_dump.find("From today's featured article")
idx2=txt_dump.find("Recently featured")

# %%
print(txt_dump[idx1+len("From today's featured article"):idx2])
# Out:
# The Tower House, in the district of Holland Park in Kensington and Chelsea, London, is a late Victorian townhouse built between 1875 and 1881 by the architect and designer William Burges as his personal residence. Designed in the French Gothic Revival style, it echoes elements of Burges's earlier work. The house was built of red brick by the Ashby Brothers, with a distinctive cylindrical tower and conical roof. The interior was decorated by members of Burges's long-standing team of craftsmen including Thomas Nicholls and Henry Stacy Marks. The house retains most of its internal structural decoration, but much of the furniture, fittings and contents that Burges designed have been dispersed. Many items, including the Great Bookcase, the Zodiac settle, the Golden Bed and the Red Bed, are now in institutions such as The Higgins Bedford and the Victoria and Albert Museum. The house was designated a Grade I listed building in 1949. (Full article...)

# %% [markdown]
# ### Exercise 9: Try to extract the important historical events that happened on today's date...

# %%
idx3=txt_dump.find("On this day")

# %%
print(txt_dump[idx3+len("On this day"):idx3+len("On this day")+1000])
# Out:
# June 12: Dia dos Namorados in Brazil; Independence Day in the Philippines (1898); Loving Day in the United States (1967)
#
#
#
# Anne Frank
#
# 1798 – Following the successful French invasion of Malta, the Knights Hospitaller surrendered Malta to Napoleon, initiating two years of occupation.
# 1899 – The New Richmond tornado killed 117 people and injured 125 others in the Upper Midwest region of the United States.
# 1942 – On her thirteenth birthday, Anne Frank (pictured) began keeping a diary during the Nazi occupation of the Netherlands in World War II.
# 1991 – More than 150 Sri Lankan Tamil civilians were massacred by members of the military in the village of Kokkadichcholai.
# Thomas Farnaby  (d. 1647)Egwale Seyon  (d. 1818)Javed Miandad  (b. 1957)
#
# More anniversaries:
# June 11
# June 12
# June 13
#
#
# Archive
# By email
# List of days of the year
#
#
#
#
# Today's featured picture
#
#
#
#
#
#
# The Notre-Dame fire broke out in the cathedral of Notre-Dame de Paris on 15 April 2019, causing severe damage to the building

# %% [markdown]
# ### Exercise 10: Use advanced BS4 technique to extract relevant text without guessing or hard coding where to look

# %%
for d in soup.find_all('div'):
        if (d.get('id')=='mp-otd'):
            for i in d.find_all('ul'):
                print(i.text)
# Out:
# 1798 – Following the successful French invasion of Malta, the Knights Hospitaller surrendered Malta to Napoleon, initiating two years of occupation.
# 1899 – The New Richmond tornado killed 117 people and injured 125 others in the Upper Midwest region of the United States.
# 1942 – On her thirteenth birthday, Anne Frank (pictured) began keeping a diary during the Nazi occupation of the Netherlands in World War II.
# 1991 – More than 150 Sri Lankan Tamil civilians were massacred by members of the military in the village of Kokkadichcholai.
# Thomas Farnaby  (d. 1647)Egwale Seyon  (d. 1818)Javed Miandad  (b. 1957)
# June 11
# June 12
# June 13
# Archive
# By email
# List of days of the year

# %%
text_list=[]
for d in soup.find_all('div'):
        if (d.get('id')=='mp-otd'):
            for i in d.find_all('ul'):
                text_list.append(i.text)

# %%
len(text_list)
# Out:
# 4

# %%
for i in text_list:
    print(i)
    print('-'*100)
# Out:
# 1798 – Following the successful French invasion of Malta, the Knights Hospitaller surrendered Malta to Napoleon, initiating two years of occupation.
# 1899 – The New Richmond tornado killed 117 people and injured 125 others in the Upper Midwest region of the United States.
# 1942 – On her thirteenth birthday, Anne Frank (pictured) began keeping a diary during the Nazi occupation of the Netherlands in World War II.
# 1991 – More than 150 Sri Lankan Tamil civilians were massacred by members of the military in the village of Kokkadichcholai.
# ----------------------------------------------------------------------------------------------------
# Thomas Farnaby  (d. 1647)Egwale Seyon  (d. 1818)Javed Miandad  (b. 1957)
# ----------------------------------------------------------------------------------------------------
# June 11
# June 12
# June 13
# ----------------------------------------------------------------------------------------------------
# Archive
# By email
# List of days of the year
# ----------------------------------------------------------------------------------------------------

# %%
print(text_list[0])
# Out:
# 1798 – Following the successful French invasion of Malta, the Knights Hospitaller surrendered Malta to Napoleon, initiating two years of occupation.
# 1899 – The New Richmond tornado killed 117 people and injured 125 others in the Upper Midwest region of the United States.
# 1942 – On her thirteenth birthday, Anne Frank (pictured) began keeping a diary during the Nazi occupation of the Netherlands in World War II.
# 1991 – More than 150 Sri Lankan Tamil civilians were massacred by members of the military in the village of Kokkadichcholai.

# %% [markdown]
# ### Functionalize this process i.e. write a compact function to extract "On this day" text from Wikipedia Home Page

# %%
def wiki_on_this_day(url="https://en.wikipedia.org/wiki/Main_Page"):
    """
    Extracts the text corresponding to the "On this day" section on the Wikipedia Home Page.
    Accepts the Wikipedia Home Page URL as a string, a default URL is provided.
    """
    import requests
    from bs4 import BeautifulSoup
    
    wiki_home = str(url)
    response = requests.get(wiki_home)
    
    def status_check(r):
        if r.status_code==200:
            return 1
        else:
            return -1
    
    status = status_check(response)
    if status==1:
        contents = decode_content(response,encoding_check(response))
    else:
        print("Sorry could not reach the web page!")
        return -1
    
    soup = BeautifulSoup(contents, 'html.parser')
    text_list=[]
    
    for d in soup.find_all('div'):
            if (d.get('id')=='mp-otd'):
                for i in d.find_all('ul'):
                    text_list.append(i.text)
    
    return (text_list[0])

# %%
print(wiki_on_this_day())
# Out:
# 1798 – Following the successful French invasion of Malta, the Knights Hospitaller surrendered Malta to Napoleon, initiating two years of occupation.
# 1899 – The New Richmond tornado killed 117 people and injured 125 others in the Upper Midwest region of the United States.
# 1942 – On her thirteenth birthday, Anne Frank (pictured) began keeping a diary during the Nazi occupation of the Netherlands in World War II.
# 1991 – More than 150 Sri Lankan Tamil civilians were massacred by members of the military in the village of Kokkadichcholai.

# %% [markdown]
# #### A wrong URL produces an error message as expected

# %%
print(wiki_on_this_day("https://en.wikipedia.org/wiki/Main_Page1"))
# Out:
# Sorry could not reach the web page!
# -1
